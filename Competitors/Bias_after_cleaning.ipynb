# %%
import pandas as pd
import spacy
import string
from langdetect import detect
import re 
import nltk
from nltk.corpus import stopwords
from gensim.models import Phrases
from gensim.corpora import Dictionary
from gensim.models import LdaModel

nlp = spacy.load("en_core_web_lg")

contractions_dict = { "ain’t": "are not", "’s":" is", "aren’t": "are not", "can’t": "cannot", 
                     "can’t’ve": "cannot have", "’cause": "because", "could’ve": "could have", 
                     "couldn’t": "could not", "couldn’t've": "could not have", "didn’t": "did not", 
                     "doesn’t": "does not", "don’t": "do not", "hadn’t": "had not", 
                     "hadn’t’ve": "had not have", "hasn’t": "has not", "haven’t": "have not",
                     "he’d": "he would", "he’d’ve": "he would have", "he’ll": "he will", 
                     "he’ll’ve": "he will have", "how’d": "how did", "how’d’y": "how do you", 
                     "how’ll": "how will", "i’d": "i would", "i’d’ve": "i would have", "i’ll": "i will",
                     "i’ll’ve": "i will have", "i’m": "i am", "i’ve": "i have", "isn’t": "is not",
                     "it’d": "it would", "it’d’ve": "it would have", "it’ll": "it will", 
                     "it’ll’ve": "it will have", "let’s": "let us", "ma’am": "madam", "mayn’t": "may not",
                     "might’ve": "might have", "mightn’t": "might not", "mightn’t’ve": "might not have",
                     "must’ve": "must have", "mustn’t": "must not", "mustn’t’ve": "must not have",
                     "needn’t": "need not", "needn’t’ve": "need not have", "o’clock": "of the clock",
                     "oughtn’t": "ought not", "oughtn’t’ve": "ought not have", "shan’t": "shall not",
                     "sha’n’t": "shall not", "shan’t’ve": "shall not have", "she’d": "she would",
                     "she’d’ve": "she would have", "she’ll": "she will", "she’ll’ve": "she will have", 
                     "should’ve": "should have", "shouldn’t": "should not", "shouldn’t’ve": "should not have",
                     "so’ve": "so have", "that’d": "that would", "that’d’ve": "that would have",
                     "there’d": "there would", "there’d’ve": "there would have", "they’d": "they would",
                     "they’d’ve": "they would have","they’ll": "they will", "they’ll’ve": "they will have",
                     "they’re": "they are", "they’ve": "they have", "to’ve": "to have", "wasn’t": "was not",
                     "we’d": "we would", "we’d’ve": "we would have", "we’ll": "we will", "we’ll’ve": "we will have",
                     "we’re": "we are", "we’ve": "we have", "weren’t": "were not","what’ll": "what will",
                     "what’ll've": "what will have", "what’re": "what are", "what’ve": "what have",
                     "when’ve": "when have", "where’d": "where did", "where’ve": "where have", 
                     "who’ll": "who will", "who’ll’ve": "who will have", "who’ve": "who have",
                     "why’ve": "why have", "will’ve": "will have", "won’t": "will not",
                     "won’t’ve": "will not have", "would’ve": "would have", "wouldn’t": "would not",
                     "wouldn’t’ve": "would not have", "y’all": "you all", "y’all’d": "you all would",
                     "y’all’d'’ve": "you all would have", "y’all’re": "you all are",
                     "y’all’ve": "you all have", "you’d": "you would", "you’d’ve": "you would have",
                     "you’ll": "you will", "you’ll’ve": "you will have", "you’re": "you are",
                     "you’ve": "you have"}


def expand_contractions(s, contractions_dict=contractions_dict):
  contractions_re = re.compile('(%s)'%'|'.join(contractions_dict.keys()))
  def replace(match):
    return contractions_dict[match.group(0)]
  return contractions_re.sub(replace, s)


def clean_hashtag_url(post):
    """
    remove all hastags and website links from a string
    """    

    return " ".join(word for word in post.split(' ') if ("#" not in word and "http" not in word))

def punct_space(token):
    """
    helper function to eliminate tokens
    that are pure punctuation or whitespace
    """

    return token.is_punct or token.is_space

def rm_pattern(post):
    """
    function returning a string without "...see more" and website links from the post. 
    This function uses "re.sub" to remove a specific pattern"""

    post = re.sub("…see more",'', post) # replace pattern by an empty string
    post = re.sub('http','',post)
    return post

def preprocess(post):
    
    clean_text = post.translate(str.maketrans("", "", string.punctuation))
    clean_text = clean_text.replace("\n", " ")
    clean_text = clean_text.replace("\u200d", "")
    clean_text = clean_text.replace("\u200b", "")
    clean_text = clean_text.replace("▪", "")
    clean_text = clean_text.replace("’", "")
    clean_text = clean_text.replace("”", "")
    clean_text = clean_text.lower()
    stop_words = set(stopwords.words('english')) - {'we', 'i', 'you', 'our', 'himself', 'herself', 'him', 'hers', 'his', 'her', 'ourselves', 'themselves', 'ours'}
    clean_text = " ".join([word for word in clean_text.split() if word not in stop_words])
    clean_text = " ".join(clean_text.split())
    
    return clean_text

def rules(token):
    """
    conditions to select a specific token for the corpus cleaning
    used with all() function : return True if all True.
    Conditions are : no pure puncuation - no pure whitespace - not a stopword 
    - not a #word
    """

    return [not punct_space(token)] 

def corpus_cleaning(posts):
    """
    generator function using spaCy to parse posts,
    remove "...see more" pattern, website links, lemmatize the text, lowercase words, and apply all the conditions we have set in rules.
    What this function returns is a generator (a "list") of individual tokens contained in lists. 
    """
    
    for post in nlp.pipe(posts.apply(rm_pattern)):
        yield ' '.join([token.lemma_ for token in post if all(rules(token))])

def main_token(json_name,column_name_corpus):

    nltk.download('stopwords')
    df = pd.read_json(json_name)

    df['language'] = df[column_name_corpus].apply(detect)
    df=df[df['language']!= 'es'].drop('language', axis=1)

    corpus=df[column_name_corpus]

    corpus = corpus.apply(expand_contractions)

    corpus = corpus.apply(clean_hashtag_url)
    corpus = corpus.apply(preprocess)

    preprocessed_posts = corpus_cleaning(corpus)
    streamed_posts = (post.split(' ') for post in preprocessed_posts)
    all_posts = []
    for streamed_post in streamed_posts:
        post = ' '.join(streamed_post)
        all_posts.append(post)

    # Process after cleaning

    df['descripcion_clean'] = all_posts

    preprocessed_posts = corpus_cleaning(corpus)
    streamed_posts = (post.split(' ') for post in preprocessed_posts)
    bigram_model = Phrases(streamed_posts,min_count=5,threshold=10)

    bigram_posts = []

    preprocessed_posts = corpus_cleaning(corpus)
    streamed_posts = (post.split(' ') for post in preprocessed_posts)

    for streamed_post in streamed_posts:
        bigram_post = ' '.join(bigram_model[streamed_post])
        bigram_posts.append(bigram_post)

    clean_corpus=bigram_posts

    return clean_corpus

# %%
clean_corpus=main_token("accenture_linkedin.json","content")
print(clean_corpus)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wdmoreno\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['ready enter virtual world discover new frontier create strong bond brand business profit check our full report', 'ever_wonder technological advancement today life business tomorrow explore next frontier tech innovation', 'disruptionproof workflow fiction it reality industrial business tool need increase efficiency transparency already learn', 'truly new possibility lie ahead we arrive exciting frontier technology innovation explore four trend_shape future discover', '🗓 ️ save date key technology trend emerge our physical virtual world blend one share reality join_we special event we explore trend_shape business technology next_decade rsvp today', 'next wave business transformation merge our digital physical world create radically new opportunity business leader available we share 4 digital trend_shape future our new share reality 🔮', 'invest people reduce our impact planet we measure value across area our business explore drive change make', 'reinvention long onetime execution continuous strategy redefine industry benchmark find get', 'today consumer expect nothing less seamlessly connect predictive experience even vehicle automaker plan meet', 'social platform do_not feel social anymore people seek new place feel sense belong learn image report collaboration ai our designer', '2023 year tag woman life boldly live without limit inspire everyone around her video description animation text keep hype vibe going follow additional text dream live thrive final frame text international woman day without limit', 'lead_way explore guideline responsible', 'gender determine our value potential jess majekodunmi share work accenture allow she pursue her career dream without limit champion diversity help other description video open jess follow text world without equality jess majekodunmi sheherhers manage_director dock ireland follow text everyone grow regardless gender end text celebrate international woman day right without limit', 'wrap we explore connect technology heart total enterprise reinvention you miss we barcelona here look highlight', 'keep people disengage notion work employer need find right solution return officelearn image report collaboration ai our designer', 'energy absolutely electric we pass halfway point excited sleep much innovation around we plus electric dogswatch andy w mathangi share buzz barcelona discuss company transform business network digital core', 'barcelona explore industry transform business experience customer serve while reveal new path growth process learn', 'activate power datum tech people boost profitability revenue but 5 company making happen 📈 here look empower growth accelerate', 'we see value direction what we create also progress we make toward our part greater good 360_° value reporting experience our way show we empower positive change across dimension help our community read full report', 'countdown less week we barcelona share our vision communication connectivitybase service pathway profitability communication service provider see we store mwc', 'we know value you unlock read our full', 'save date join_we live explore future communication industry include network transformation mean consumer impact massive investment telecommunication company rsvp today', 'company free nearly two hour employee workday accelerate radical growth swipe ⬇ ️ learn', '🛍 ️ 😍 more ever people feel need connect and change way we interact brand we love we want consumer we want participant find shift our report', 'ever_wonder we create our industry_x spot you_know ⬇ ️ 💜 🤗 learn', 'samta kapoor md industrial cluster change future climate_change we combine automate intelligence human intelligence wire', 'right thing get people board learn create strategy establish principle responsible innovation', 'everyone role play create protect our digital environment at_work everyday life discover you part 5 action straight our', 'thrilled share we reach our high brand finance rank ever we also proud valuable service brand 5t ...

# %% [markdown]
# ## NLP Analysis

# %%
import nltk
nltk.download('punkt')

corpus_tok = [nltk.word_tokenize(sent) for sent in clean_corpus]
corpus_tok
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\wdmoreno\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['ready',
#   'enter',
#   'virtual',
#   'world',
#   'discover',
#   'new',
#   'frontier',
#   'create',
#   'strong',
#   'bond',
#   'brand',
#   'business',
#   'profit',
#   'check',
#   'our',
#   'full',
#   'report'],
#  ['ever_wonder',
#   'technological',
#   'advancement',
#   'today',
#   'life',
#   'business',
#   'tomorrow',
#   'explore',
#   'next',
#   'frontier',
#   'tech',
#   'innovation'],
#  ['disruptionproof',
#   'workflow',
#   'fiction',
#   'it',
#   'reality',
#   'industrial',
#   'business',
#   'tool',
#   'need',
#   'increase',
#   'efficiency',
#   'transparency',
#   'already',
#   'learn'],
#  ['truly',
#   'new',
#   'possibility',
#   'lie',
#   'ahead',
#   'we',
#   'arrive',
#   'exciting',
#   'frontier',
#   'technology',
#   'innovation',
#   'explore',
#   'four',
#   'trend_shape',
#   'future',
#   'discover'],
#  ['🗓',
#   '️',
#   'save',
#   'date',
#   'key',
#   'technology',
#   'trend',
#   'emerge',
#   'our',
#   'physical',
#   'virtual',
#   'world',
#   'blend',
#   'one',
#   'share',
#   'reality',
#   'join_we',
#   'special',
#   'event',
#   'we',
#   'explore',
#   'trend_shape',
#   'business',
#   'technology',
#   'next_decade',
#   'rsvp',
#   'today'],
#  ['next',
#   'wave',
#   'business',
#   'transformation',
#   'merge',
#   'our',
#   'digital',
#   'physical',
#   'world',
#   'create',
#   'radically',
#   'new',
#   'opportunity',
#   'business',
#   'leader',
#   'available',
#   'we',
#   'share',
#   '4',
#   'digital',
#   'trend_shape',
#   'future',
#   'our',
#   'new',
#   'share',
#   'reality',
#   '🔮'],
#  ['invest',
#   'people',
#   'reduce',
#   'our',
#   'impact',
#   'planet',
#   'we',
#   'measure',
#   'value',
#   'across',
#   'area',
#   'our',
#   'business',
#   'explore',
#   'drive',
#   'change',
#   'make'],
#  ['reinvention',
#   'long',
#   'onetime',
#   'execution',
#   'continuous',
#   'strategy',
#   'redefine',
#   'industry',
#   'benchmark',
#   'find',
#   'get'],
#  ['today',
#   'consumer',
#   'expect',
#   'nothing',
#   'less',
#   'seamlessly',
#   'connect',
#   'predictive',
#   'experience',
#   'even',
#   'vehicle',
#   'automaker',
#   'plan',
#   'meet'],
#  ['social',
#   'platform',
#   'do_not',
#   'feel',
#   'social',
#   'anymore',
#   'people',
#   'seek',
#   'new',
#   'place',
#   'feel',
#   'sense',
#   'belong',
#   'learn',
#   'image',
#   'report',
#   'collaboration',
#   'ai',
#   'our',
#   'designer'],
#  ['2023',
#   'year',
#   'tag',
#   'woman',
#   'life',
#   'boldly',
#   'live',
#   'without',
#   'limit',
#   'inspire',
#   'everyone',
#   'around',
#   'her',
#   'video',
#   'description',
#   'animation',
#   'text',
#   'keep',
#   'hype',
#   'vibe',
#   'going',
#   'follow',
#   'additional',
#   'text',
#   'dream',
#   'live',
#   'thrive',
#   'final',
#   'frame',
#   'text',
#   'international',
#   'woman',
#   'day',
#   'without',
#   'limit'],
#  ['lead_way', 'explore', 'guideline', 'responsible'],
#  ['gender',
#   'determine',
#   'our',
#   'value',
#   'potential',
#   'jess',
#   'majekodunmi',
#   'share',
#   'work',
#   'accenture',
#   'allow',
#   'she',
#   'pursue',
#   'her',
#   'career',
#   'dream',
#   'without',
#   'limit',
#   'champion',
#   'diversity',
#   'help',
#   'other',
#   'description',
#   'video',
#   'open',
#   'jess',
#   'follow',
#   'text',
#   'world',
#   'without',
#   'equality',
#   'jess',
#   'majekodunmi',
#   'sheherhers',
#   'manage_director',
#   'dock',
#   'ireland',
#   'follow',
#   'text',
#   'everyone',
#   'grow',
#   'regardless',
#   'gender',
#   'end',
#   'text',
#   'celebrate',
#   'international',
#   'woman',
#   'day',
#   'right',
#   'without',
#   'limit'],
#  ['wrap',
#   'we',
#   'explore',
#   'connect',
#   'technology',
#   'heart',
#   'total',
#   'enterprise',
#   'reinvention',
#   'you',
#   'miss',
#   'we',
#   'barcelona',
#   'here',
#   'look',
#   'highlight'],
#  ['keep',
#   'people',
#   'disengage',
#   'notion',
#   'work',
#   'employer',
#   'need',
#   'find',
#   'right',
#   'solution',
#   'return',
#   'officelearn',
#   'image',
#   'report',
#   'collaboration',
#   'ai',
#   'our',
#   'designer'],
#  ['energy',
#   'absolutely',
#   'electric',
#   'we',
#   'pass',
#   'halfway',
#   'point',
#   'excited',
#   'sleep',
#   'much',
#   'innovation',
#   'around',
#   'we',
#   'plus',
#   'electric',
#   'dogswatch',
#   'andy',
#   'w',
#   'mathangi',
#   'share',
#   'buzz',
#   'barcelona',
#   'discuss',
#   'company',
#   'transform',
#   'business',
#   'network',
#   'digital',
#   'core'],
#  ['barcelona',
#   'explore',
#   'industry',
#   'transform',
#   'business',
#   'experience',
#   'customer',
#   'serve',
#   'while',
#   'reveal',
#   'new',
#   'path',
#   'growth',
#   'process',
#   'learn'],
#  ['activate',
#   'power',
#   'datum',
#   'tech',
#   'people',
#   'boost',
#   'profitability',
#   'revenue',
#   'but',
#   '5',
#   'company',
#   'making',
#   'happen',
#   '📈',
#   'here',
#   'look',
#   'empower',
#   'growth',
#   'accelerate'],
#  ['we',
#   'see',
#   'value',
#   'direction',
#   'what',
#   'we',
#   'create',
#   'also',
#   'progress',
#   'we',
#   'make',
#   'toward',
#   'our',
#   'part',
#   'greater',
#   'good',
#   '360_°',
#   'value',
#   'reporting',
#   'experience',
#   'our',
#   'way',
#   'show',
#   'we',
#   'empower',
#   'positive',
#   'change',
#   'across',
#   'dimension',
#   'help',
#   'our',
#   'community',
#   'read',
#   'full',
#   'report'],
#  ['countdown',
#   'less',
#   'week',
#   'we',
#   'barcelona',
#   'share',
#   'our',
#   'vision',
#   'communication',
#   'connectivitybase',
#   'service',
#   'pathway',
#   'profitability',
#   'communication',
#   'service',
#   'provider',
#   'see',
#   'we',
#   'store',
#   'mwc'],
#  ['we', 'know', 'value', 'you', 'unlock', 'read', 'our', 'full'],
#  ['save',
#   'date',
#   'join_we',
#   'live',
#   'explore',
#   'future',
#   'communication',
#   'industry',
#   'include',
#   'network',
#   'transformation',
#   'mean',
#   'consumer',
#   'impact',
#   'massive',
#   'investment',
#   'telecommunication',
#   'company',
#   'rsvp',
#   'today'],
#  ['company',
#   'free',
#   'nearly',
#   'two',
#   'hour',
#   'employee',
#   'workday',
#   'accelerate',
#   'radical',
#   'growth',
#   'swipe',
#   '⬇',
#   '️',
#   'learn'],
#  ['🛍',
#   '️',
#   '😍',
#   'more',
#   'ever',
#   'people',
#   'feel',
#   'need',
#   'connect',
#   'and',
#   'change',
#   'way',
#   'we',
#   'interact',
#   'brand',
#   'we',
#   'love',
#   'we',
#   'want',
#   'consumer',
#   'we',
#   'want',
#   'participant',
#   'find',
#   'shift',
#   'our',
#   'report'],
#  ['ever_wonder',
#   'we',
#   'create',
#   'our',
#   'industry_x',
#   'spot',
#   'you_know',
#   '⬇',
#   '️',
#   '💜',
#   '🤗',
#   'learn'],
#  ['samta',
#   'kapoor',
#   'md',
#   'industrial',
#   'cluster',
#   'change',
#   'future',
#   'climate_change',
#   'we',
#   'combine',
#   'automate',
#   'intelligence',
#   'human',
#   'intelligence',
#   'wire'],
#  ['right',
#   'thing',
#   'get',
#   'people',
#   'board',
#   'learn',
#   'create',
#   'strategy',
#   'establish',
#   'principle',
#   'responsible',
#   'innovation'],
#  ['everyone',
#   'role',
#   'play',
#   'create',
#   'protect',
#   'our',
#   'digital',
#   'environment',
#   'at_work',
#   'everyday',
#   'life',
#   'discover',
#   'you',
#   'part',
#   '5',
#   'action',
#   'straight',
#   'our'],
#  ['thrilled',
#   'share',
#   'we',
#   'reach',
#   'our',
#   'high',
#   'brand',
#   'finance',
#   'rank',
#   'ever',
#   'we',
#   'also',
#   'proud',
#   'valuable',
#   'service',
#   'brand',
#   '5th',
#   'year',
#   'row',
#   'together',
#   'we',
#   'make',
#   'progress',
#   'create',
#   '360º',
#   'value',
#   'every_day',
#   'around_world'],
#  ['introduce',
#   'new',
#   'strategy',
#   'future',
#   'one',
#   'way',
#   'business',
#   'expand',
#   'beyond',
#   'industry',
#   'borderstech',
#   'leader',
#   'qualcomm',
#   'need',
#   'new',
#   'avenue',
#   'growth',
#   'start',
#   'broaden',
#   'mindset',
#   'around',
#   'offer',
#   'exist',
#   'tech',
#   'talent',
#   'learn',
#   'transform',
#   'business'],
#  ['be_not',
#   'beautiful',
#   '💜',
#   'see',
#   'our',
#   'sustainable',
#   'trophy',
#   'design',
#   'our',
#   'v360',
#   'award',
#   'create',
#   'learn',
#   'work',
#   'we'],
#  ['let', 'we', 'know', 'you', 'thinkread', 'our', 'report', 'find'],
#  ['together',
#   'international',
#   'holocaust',
#   'remembrance',
#   'day',
#   'we',
#   'remember',
#   'honor',
#   'six',
#   'million',
#   'victim',
#   'nazi',
#   'persecution',
#   'important',
#   'time',
#   'pause',
#   'reflect',
#   'continue',
#   'take',
#   'action',
#   'hate',
#   'discrimination',
#   'antisemitism',
#   'racismaccenture',
#   'volunteer',
#   'around_world',
#   'work',
#   'help',
#   'preserve',
#   'name',
#   'story',
#   'our',
#   'ai',
#   'project',
#   'arolsen',
#   'archive',
#   'organization',
#   'create',
#   'massive',
#   'digital',
#   'memorial',
#   'victim',
#   'nazi',
#   'persecution',
#   'see',
#   'story',
#   'our',
#   'colleague',
#   'share',
#   'history',
#   'family',
#   'member',
#   'fall',
#   'victim',
#   'nazism',
#   'never',
#   'forget'],
#  ['industry',
#   'city',
#   'knowledge',
#   'partner',
#   'we',
#   'excite',
#   'share',
#   'our',
#   'vision',
#   'connectivitybase',
#   'service',
#   'pathways',
#   'profitability',
#   'csp',
#   'see'],
#  ['align',
#   'our',
#   'purpose',
#   'value',
#   'our',
#   'work',
#   'we',
#   'make',
#   'meaningful',
#   'change',
#   'inclusion_diversity',
#   'our',
#   'continue',
#   'investment',
#   'lowcarbon',
#   'future',
#   'we',
#   'commit',
#   'measure',
#   'value',
#   'direction',
#   'see',
#   'our',
#   '360_°',
#   'value',
#   'reporting',
#   'experience',
#   'helped',
#   'achieve',
#   'progress'],
#  ['give',
#   'we',
#   'insight',
#   'make',
#   'well',
#   'decision',
#   'improve',
#   'worker',
#   'safety',
#   'drive',
#   'exponential',
#   'growth',
#   'business',
#   'see',
#   'deliver',
#   'value',
#   'our',
#   'life',
#   'work',
#   'three',
#   'different',
#   'perspective',
#   'include',
#   'our',
#   'lan',
#   'guan',
#   'wire'],
#  ['we',
#   'find',
#   '1',
#   'sport',
#   'fan',
#   'attend',
#   'athletic',
#   'event',
#   'live',
#   'year',
#   'inperson',
#   'experience',
#   'drive',
#   'love',
#   'game',
#   'our',
#   'work',
#   'revel',
#   'moment',
#   'we',
#   'uncover',
#   'importance',
#   'human',
#   'connection',
#   'athlete',
#   'big',
#   'fan',
#   'we',
#   'create',
#   'platform',
#   'athlete',
#   'tell',
#   'untold',
#   'story',
#   'fan',
#   'see',
#   'human',
#   'side',
#   'heroeslearn',
#   'brand',
#   'athlete',
#   'work',
#   'revel',
#   'moment',
#   'intimately',
#   'connect',
#   'fan',
#   'customer'],
#  ['wrap',
#   'day',
#   '2',
#   'swipe',
#   'see',
#   'happen',
#   'ground',
#   'expand',
#   'link',
#   '⬇',
#   '➡',
#   '️',
#   'our',
#   'full',
#   'agenda',
#   'foresight',
#   '15',
#   'replay',
#   'feature',
#   'paul_daugherty',
#   'jill_kramer',
#   'breakthrough',
#   'innovation',
#   'full',
#   'report',
#   'ft',
#   'live',
#   'accenture',
#   'panel',
#   'feature',
#   'jean',
#   'marc',
#   'ollagnier',
#   'accelerate',
#   'europe',
#   'path',
#   'reinvention',
#   'report',
#   'global',
#   'citizen',
#   'linkedin',
#   'live',
#   'discussion',
#   'feature',
#   'ellyn_shake',
#   'hugh',
#   'evans',
#   'dr',
#   'adanna',
#   'steinacker',
#   'pgle',
#   'download',
#   'accenture_foresight'],
#  ['icymi',
#   'watch',
#   'replay',
#   'wednesday',
#   'foresight',
#   '15',
#   'broadcast',
#   'feature',
#   'paul_daugherty',
#   'jill_kramer',
#   'breakthrough',
#   'innovation',
#   'learn',
#   'strong',
#   'digital',
#   'core',
#   'bring',
#   'together',
#   'application',
#   'via',
#   'key',
#   'competitive',
#   'differentiation',
#   'reinvention',
#   'innovation',
#   'download',
#   'accenture_foresight',
#   'catch',
#   'our',
#   'next',
#   'episode',
#   'live',
#   'experience',
#   'exclusive',
#   'content'],
#  ['organization',
#   'equip',
#   'breakthrough',
#   'innovationour',
#   'report',
#   'show',
#   '3',
#   'tech',
#   'key',
#   'competitive',
#   'differentiation',
#   'reinvention',
#   'innovation'],
#  ['time',
#   'company',
#   'look',
#   'new',
#   'way',
#   'forward',
#   'we',
#   'find',
#   'influential',
#   'factor',
#   'right',
#   'csuite',
#   'discover',
#   'highre',
#   'chros',
#   'focus',
#   'power',
#   'datum',
#   'tech',
#   'people',
#   'accelerate',
#   'reinventionsee',
#   'new',
#   'vision',
#   'growth'],
#  ['day',
#   '1',
#   'book',
#   'swipe',
#   'see',
#   'we',
#   'expand',
#   'link',
#   'learn',
#   '⬇',
#   '1️⃣',
#   'our',
#   'full',
#   'agenda',
#   'foresight',
#   '15',
#   'replay',
#   'feature',
#   'kathleen',
#   'oreilly',
#   'jack',
#   'azagury',
#   'jill_kramer',
#   'total',
#   'enterprise',
#   'reinvention',
#   'full',
#   'report',
#   'wef23',
#   'preview',
#   'jack',
#   'azagury',
#   'global',
#   'collaboration',
#   'village',
#   'panel',
#   'replay',
#   'feature',
#   'julie_sweet',
#   'technology',
#   'resilient',
#   'world',
#   'session',
#   'replay',
#   'download',
#   'accenture_foresight'],
#  ['icymi',
#   'watch',
#   'replay',
#   'our',
#   'foresight',
#   '15',
#   'broadcast',
#   'davo',
#   'learn',
#   'you',
#   'become',
#   'reinventor',
#   'set',
#   'new',
#   'performance',
#   'frontier',
#   'organizationdownload',
#   'our',
#   'accenture_foresight',
#   'app',
#   'catch',
#   'tomorrow',
#   'episode',
#   'live',
#   'access',
#   'exclusive',
#   'content'],
#  ['extraordinary',
#   'time',
#   'call',
#   'unprecedented',
#   'response',
#   'executive',
#   'agree',
#   'need',
#   'transform',
#   'ever',
#   'yet',
#   '8',
#   'company',
#   'moving',
#   'adopt',
#   'holistic',
#   'approach',
#   'transformation',
#   'we',
#   'call',
#   'total',
#   'enterprise',
#   'reinvention',
#   'explore',
#   '6',
#   'characteristic',
#   'define',
#   'new',
#   'strategy'],
#  ['field',
#   'beyond',
#   'mainstream',
#   'medium',
#   'revel',
#   'moment',
#   'offer',
#   'fan',
#   'athlete',
#   'space',
#   'connect',
#   'human',
#   'level',
#   'create',
#   'platform',
#   'transcend',
#   'game',
#   'day',
#   'geography',
#   'status',
#   'require',
#   'total',
#   'reinvention',
#   'traditional',
#   'fan',
#   'experience',
#   'twoway',
#   'interactive',
#   'virtual',
#   'platform',
#   'fandriven',
#   'pricing',
#   'custom',
#   'nft',
#   'ticket',
#   'every',
#   'experience',
#   'carefully',
#   'curate',
#   'discover',
#   'our',
#   'partnership',
#   'we',
#   'helping',
#   'restore',
#   'connection',
#   'fan',
#   'favorite',
#   'player'],
#  ['🎥',
#   'check',
#   'our',
#   'broadcast',
#   'agenda',
#   'moderate',
#   'our',
#   'jill_kramer',
#   '📲',
#   'download',
#   'our',
#   'free',
#   'accenture_foresight',
#   'app',
#   'watch',
#   'live',
#   'access',
#   'exclusive',
#   'content'],
#  ['look',
#   'wing',
#   '🐶',
#   '🤩',
#   '✨',
#   'take',
#   'you',
#   'backstage',
#   'creation',
#   'our',
#   'futuristic',
#   'industry_x',
#   'dog',
#   'see',
#   'we',
#   'help',
#   'client',
#   'digitize',
#   'revolutionize',
#   'product'],
#  ['ceos',
#   'embrace',
#   'sustainability',
#   'chart',
#   'course',
#   'resilient',
#   'competitive',
#   'future',
#   'our',
#   'new',
#   'study',
#   'united_nations',
#   'global_compact',
#   'outline',
#   'action',
#   'leader',
#   'take',
#   'key',
#   'ask'],
#  ['capital',
#   'cnbc',
#   'name',
#   'we',
#   'our',
#   'industry',
#   'overall',
#   'annual',
#   'list',
#   'recognize',
#   'our',
#   'leadership',
#   'financial',
#   'environmental',
#   'social',
#   'governance',
#   'issue',
#   'matter',
#   'american',
#   'public',
#   'thank_you',
#   'our',
#   'incredible_people',
#   'drive',
#   'change',
#   'deliver',
#   '360_°',
#   'value'],
#  ['imagine',
#   'you',
#   'give',
#   'opportunity',
#   'fully',
#   'immersive',
#   'virtual',
#   'reality',
#   'experience',
#   'location',
#   'choose',
#   'virtual',
#   'reality',
#   'environment',
#   'would',
#   'you',
#   'want',
#   'explore',
#   'favorite',
#   'sport',
#   'team',
#   'stadium',
#   '🥇',
#   'the',
#   'city',
#   'top',
#   'bucket',
#   'list',
#   '🏙',
#   'outer',
#   'space',
#   '🌌',
#   'with',
#   'technology',
#   'experience',
#   'possible',
#   'see',
#   'partner',
#   'disneys',
#   'studiolab',
#   'push',
#   'boundary',
#   'shape',
#   'next_generation',
#   'storytelle'],
#  ['imagine',
#   'future',
#   'industry',
#   'could',
#   'productive',
#   'sustainable',
#   '🌎',
#   'find',
#   'we',
#   'reimagine',
#   'product',
#   'we',
#   'make',
#   'we',
#   'make'],
#  ['hyperloop',
#   'check',
#   'box',
#   'ideal',
#   'alternative',
#   'short',
#   'haul',
#   'flight',
#   '☑',
#   'fast',
#   'airplane',
#   'comfortable',
#   'train',
#   'safe',
#   'sustainable',
#   'imagining',
#   'would',
#   'like',
#   'travel',
#   'via',
#   'challenge',
#   'important',
#   'first',
#   'step',
#   'embrace',
#   'new',
#   'way',
#   'travel',
#   'which',
#   'we',
#   'bring',
#   'virtual',
#   'hyperloop',
#   'experience',
#   'step',
#   'year',
#   '2028',
#   'take',
#   'seat',
#   'hardt',
#   'hyperloop',
#   'cabin1'],
#  ['explore',
#   'fashion',
#   'new',
#   'terrain',
#   'sit',
#   'front',
#   'row',
#   'virtual',
#   'fashion',
#   'show',
#   '👠',
#   'see',
#   'reimagine',
#   'customer',
#   'engagement',
#   'use',
#   'salesforce',
#   'crm',
#   'technology'],
#  ['provide',
#   'new',
#   'opportunity',
#   'fundamentally',
#   'change',
#   'we',
#   'live',
#   'work',
#   'continue',
#   'evolve',
#   'rapid',
#   'pace',
#   'shape',
#   'reshape',
#   'enterprise',
#   'function',
#   'the',
#   'metaverse',
#   'create',
#   'value',
#   'business',
#   'across',
#   'industry',
#   'here',
#   'change',
#   'world',
#   'we',
#   'know'],
#  ['volumetric',
#   'video',
#   'capture',
#   'enable',
#   'people',
#   'show',
#   'human',
#   'way',
#   'see'],
#  ['save',
#   'date',
#   'take',
#   'you',
#   'onto',
#   'show',
#   'floor',
#   'and',
#   'join_we',
#   'special',
#   'event',
#   'well',
#   'explore',
#   'innovation',
#   'trend',
#   'technology',
#   'empower',
#   'enterprise',
#   'lead',
#   'speed',
#   'life'],
#  ['accenture_foresight',
#   'app',
#   'we',
#   'get',
#   'everything',
#   'you',
#   'need',
#   'davos',
#   '✅',
#   'live',
#   'panel',
#   'discussion',
#   '✅',
#   'awardwinning',
#   'podcast',
#   '✅',
#   'research',
#   'trend',
#   '✅',
#   'interactive',
#   'datum',
#   'chart',
#   '❌',
#   'snow',
#   'boot',
#   '🎿',
#   'okay',
#   'well',
#   'almost',
#   'everything'],
#  ['often',
#   'gap',
#   'people',
#   'want_work',
#   'employer',
#   'actually',
#   'offer',
#   'january',
#   '6',
#   'we',
#   'go',
#   'live',
#   'instagram',
#   'meta',
#   'kelly',
#   'monahan',
#   'phd',
#   'our',
#   'christie',
#   'smith',
#   'examine',
#   'well',
#   'access',
#   'digital',
#   'fluency',
#   'understand',
#   'it',
#   'can',
#   'empower',
#   'employee',
#   'lead',
#   'happy',
#   'healthy',
#   'productive',
#   'life',
#   'follow',
#   'we',
#   'instagram',
#   'accenture',
#   'tune'],
#  ['world',
#   'change',
#   'escalate',
#   'pace',
#   'you',
#   'either',
#   'lead',
#   'change',
#   'let',
#   'happen',
#   'you',
#   'help',
#   'business',
#   'take',
#   'rein',
#   'lead',
#   'speed',
#   'life',
#   'deliver',
#   'people',
#   'truly',
#   'desire',
#   'learn'],
#  ['we',
#   'speak',
#   '10yearold',
#   'artist',
#   'computer',
#   'science',
#   'student',
#   'our',
#   'expert',
#   'sanjeev',
#   'vohra',
#   'impact',
#   'our',
#   'everyday',
#   'life',
#   'watch',
#   'say',
#   'wire'],
#  ['lead',
#   'change',
#   'leave',
#   'full',
#   'heart',
#   '💜',
#   '2022',
#   'year',
#   'remember',
#   'we',
#   'can_not',
#   'wait',
#   'see',
#   '2023',
#   'bring',
#   'our',
#   'people',
#   'client',
#   'shareholder',
#   'partner',
#   'community',
#   'year',
#   'we',
#   '⛳',
#   '️',
#   'become',
#   'proud',
#   'partner',
#   'pga',
#   'tour',
#   'championship',
#   '😴',
#   'raise',
#   '600k',
#   'homeless',
#   'youth',
#   'sleep',
#   'out🟣',
#   'go',
#   'purple',
#   'illuminate',
#   'thing',
#   'inspire',
#   'new',
#   'wave',
#   'summer',
#   'intern',
#   '🏢',
#   'open',
#   'new',
#   'office',
#   'nyc',
#   'chicago',
#   'toronto'],
#  ['company',
#   'broaden',
#   'mission',
#   'around',
#   'social',
#   'environmental',
#   'economic',
#   'important',
#   'value',
#   'unlock',
#   'sustainable',
#   'advantage',
#   'help',
#   'futureproof',
#   'relevancy',
#   'inside',
#   'idea',
#   'one',
#   'element',
#   'see',
#   'full',
#   'playbook',
#   'researchbacked',
#   'insight'],
#  ['ever_wonder',
#   'we',
#   'create',
#   'our',
#   'industry_x',
#   'spot',
#   'you_know',
#   '⬇',
#   '️',
#   '💜',
#   '🤗',
#   'learn'],
#  ['master',
#   'art',
#   'ai_maturity',
#   'mean',
#   'design',
#   'ai',
#   'responsibly',
#   'whether',
#   'you',
#   're',
#   'getting',
#   'start',
#   'get',
#   'ready',
#   'scale',
#   'must',
#   'embed',
#   'every',
#   'step',
#   'process'],
#  ['strategy',
#   '➕',
#   'purpose',
#   'win',
#   'combination',
#   '🤗',
#   '💜',
#   'peek',
#   'our',
#   'business',
#   'value',
#   'and',
#   'progress',
#   'we_ve',
#   'make',
#   'create_inclusive',
#   'sustainable_future'],
#  ['we',
#   'join',
#   'last',
#   'month',
#   'illuminate',
#   'our',
#   'office',
#   'celebrate',
#   'raise',
#   'awareness',
#   'person_disability',
#   'our',
#   '2023',
#   'goal',
#   'continue',
#   'conversation',
#   'you',
#   'join_we'],
#  ['make',
#   'force',
#   'change',
#   'we',
#   'honor',
#   'earn',
#   'place',
#   'cdp',
#   'climate',
#   'list',
#   '7th',
#   'year',
#   'recognize',
#   'our',
#   'leadership',
#   'climate_change',
#   'transparency',
#   'performance'],
#  ['company',
#   'ignore',
#   'complexity',
#   'life',
#   'miss',
#   'opportunity_add',
#   'value',
#   'people',
#   'live',
#   'apply',
#   'customer',
#   'employee',
#   'fact',
#   'business',
#   'prioritize',
#   'unlock',
#   'deep',
#   'human',
#   'insight',
#   '19',
#   'likely',
#   'achieve',
#   'high',
#   'level',
#   'employee',
#   'retentionfrom',
#   'inside',
#   'good',
#   'business',
#   'learn',
#   'playbook'],
#  ['📚',
#   'here',
#   'little',
#   'holiday',
#   'read',
#   'you',
#   'insight',
#   'key',
#   'shift',
#   'our',
#   'behavior',
#   'relationship',
#   'technology',
#   'read'],
#  ['delighted',
#   'list',
#   'bestmanaged',
#   'company',
#   'accord',
#   'wall',
#   'street',
#   'journal',
#   'drucker',
#   'institute',
#   'learn',
#   'we',
#   'create',
#   '360_°',
#   'value'],
#  ['around',
#   'corner',
#   'accenture_foresight',
#   'good',
#   'way',
#   'stay',
#   'top',
#   'conversation',
#   'leader',
#   'collection',
#   'our',
#   'late',
#   'insight',
#   'download',
#   'stay',
#   'ahead',
#   'change',
#   'like',
#   'never'],
#  ['musthave',
#   'vacation',
#   'it',
#   '🥗',
#   'amazing',
#   'food',
#   '📱',
#   'strong',
#   'wifi',
#   'service',
#   '✈',
#   '️',
#   'firstclass',
#   'flight',
#   'experiencethere',
#   'one',
#   'answer',
#   'reason',
#   'we',
#   'travel',
#   'change',
#   'and',
#   'business',
#   'need',
#   'adapt',
#   'find',
#   'episode'],
#  ['🚛',
#   '🥬',
#   '📈',
#   'felix',
#   'project',
#   'want',
#   'rapidly',
#   'scale',
#   'vision',
#   'fight',
#   'food',
#   'waste',
#   'hunger',
#   'but',
#   'smart',
#   'costeffective',
#   'way',
#   'here',
#   'together',
#   'avanade',
#   'uk',
#   'ireland',
#   'microsoft',
#   'we',
#   'helped',
#   'find',
#   'techbased',
#   'solution'],
#  ['help',
#   'business',
#   'see',
#   'positive',
#   'value',
#   'every_direction',
#   'benefit',
#   'world',
#   'around',
#   'we',
#   'join_we',
#   'make',
#   'impact'],
#  ['creativity',
#   'technology',
#   'intelligence',
#   'help',
#   'edwin',
#   'build',
#   'well',
#   'web',
#   'experience',
#   'philippine',
#   'airline',
#   'traveler',
#   'staff',
#   'discover',
#   'his',
#   'career',
#   'journey',
#   'inspire',
#   'join',
#   'our',
#   'team',
#   'designer',
#   'creator',
#   'strategist'],
#  ['give',
#   'we',
#   'insight',
#   'make',
#   'well',
#   'decision',
#   'improve',
#   'worker',
#   'safety',
#   'drive',
#   'exponential',
#   'growth',
#   'business',
#   'see',
#   'deliver',
#   'value',
#   'our',
#   'life',
#   'work',
#   'three',
#   'different',
#   'perspective',
#   'include',
#   'our',
#   'lan',
#   'guan',
#   'wire'],
#  ['150',
#   'billion',
#   'garment',
#   'manufacture',
#   'worldwide',
#   'year',
#   'discover',
#   'our',
#   'harshit',
#   'management',
#   'consultant',
#   'work',
#   'our',
#   'supply_chain',
#   'practice',
#   'reduce',
#   'waste',
#   'apparel',
#   'industry'],
#  ['world',
#   'move',
#   'breakneck',
#   'pace',
#   'enterprise',
#   'accelerate',
#   'change',
#   'deliver',
#   'people',
#   'truly',
#   'want',
#   'explore',
#   'innovation',
#   'help',
#   'enterprise',
#   'lead',
#   'speed',
#   'life',
#   'see',
#   'our',
#   'agenda'],
#  ['congratulation',
#   'our',
#   'chair',
#   'ceo_julie',
#   'sweet_recognize',
#   'forbes',
#   'worlds',
#   'powerful_woman',
#   'list',
#   'thank_you',
#   'inspire',
#   'we',
#   'create',
#   'value',
#   'every_day',
#   'in',
#   'every_direction'],
#  ['postpandemic',
#   'world',
#   'travel',
#   'company',
#   'innovate',
#   'discover',
#   'new',
#   'way',
#   'accelerate',
#   'growth',
#   '✈',
#   '️',
#   '🌎',
#   'adaptability',
#   'change',
#   'technology',
#   'consumer',
#   'behavior',
#   'what',
#   'travel',
#   'trend',
#   'watch',
#   '2023',
#   'learn'],
#  ['honored',
#   'recognize',
#   'interbrand',
#   'good',
#   'global',
#   'brand',
#   'our',
#   'people',
#   'commitment',
#   'solve',
#   'world',
#   'challenge',
#   'problem',
#   'make',
#   'our',
#   'brand',
#   'strong'],
#  ['our',
#   'device',
#   'always',
#   'connect',
#   'you',
#   'really',
#   'connect',
#   'in',
#   'human',
#   'sense',
#   'at_work',
#   'our',
#   'research_show',
#   'omniconnecte_experience',
#   'level_playing',
#   'field',
#   '✨',
#   'help',
#   'we',
#   'forge',
#   'relationship',
#   '✨',
#   'create',
#   'personal',
#   'business',
#   'value',
#   'impact',
#   '✨',
#   'grow',
#   'our'],
#  ['join_we',
#   'youtube',
#   'catch',
#   'beck',
#   'baileys',
#   'conversation',
#   'molly',
#   'burke',
#   'dr',
#   'sai',
#   'kaustuv',
#   'dasgupta',
#   'contribution',
#   'person_disability',
#   'our',
#   'community',
#   'we',
#   'well',
#   'ally',
#   'join_we',
#   'alt',
#   'textpurple',
#   'background',
#   'come',
#   'screen',
#   'fade',
#   'molly',
#   'burke',
#   'talk',
#   'her',
#   'life',
#   'experience',
#   'woman',
#   'blind',
#   'screen',
#   'fade',
#   'purple',
#   'spotlight',
#   'highlight',
#   'international_day',
#   'person_disability'],
#  ['remember',
#   'our',
#   'futuristic',
#   'robot',
#   'our',
#   'industry_x',
#   'spot',
#   'watch',
#   'design',
#   'process',
#   'come',
#   '🦾',
#   '👏',
#   '💜',
#   'more',
#   'we',
#   'help',
#   'our',
#   'client',
#   'reimagine',
#   'product',
#   'make',
#   'make'],
#  ['use',
#   'analytic',
#   'help',
#   'improve',
#   'water',
#   'quality',
#   'ethiopa',
#   'teresa',
#   'make',
#   'impact',
#   'her',
#   'career',
#   'our',
#   'cloud',
#   'first',
#   'chief',
#   'technologist',
#   'want_work',
#   'like',
#   'teresa',
#   'explore',
#   'impactful',
#   'career',
#   'story'],
#  ['our',
#   'research_show',
#   'company',
#   'lead_way',
#   'outpace',
#   'growth',
#   'rate',
#   'peer',
#   'nine',
#   'percentage',
#   'point',
#   'annually',
#   'time',
#   'like',
#   'join',
#   'movement'],
#  ['join_we',
#   'instagram',
#   'nov',
#   '30',
#   'celebrate',
#   'disability_inclusion',
#   'our',
#   'host',
#   'beck',
#   'bailey',
#   'join',
#   'speaker',
#   'author',
#   'advocate',
#   'molly',
#   'burke',
#   'our',
#   'motivational',
#   'tedx',
#   'speaker',
#   'happiness',
#   'coach',
#   'sai',
#   'kaustuv',
#   'dasgupta',
#   'inspire',
#   'conversation',
#   'contribution',
#   'person_disability',
#   'make',
#   'our',
#   'workplace',
#   'society',
#   'well',
#   'we',
#   'well'],
#  ['company',
#   'master',
#   'maturity',
#   'experience',
#   '50',
#   'great',
#   'revenue_growth',
#   'peer',
#   'explore',
#   'ai_maturity',
#   'level',
#   'look',
#   'like',
#   'across',
#   'different',
#   'industry',
#   'company',
#   'size',
#   'geography'],
#  ['business',
#   'priority',
#   'line',
#   'core',
#   'value',
#   'we',
#   'call',
#   'win',
#   'combination',
#   '😎',
#   '🙌'],
#  ['future',
#   'within',
#   'reach',
#   'with',
#   'help',
#   'aisports',
#   'club',
#   'healthcare',
#   'industry',
#   'even',
#   'hr',
#   'team',
#   'use',
#   'predictive',
#   'analytic',
#   'boost',
#   'cohesion',
#   'even',
#   'avoid',
#   'potential',
#   'issue',
#   'find',
#   'business',
#   'use',
#   'largescale',
#   'simulation',
#   'make',
#   'well',
#   'decision',
#   'episode',
#   '22'],
#  ['combine',
#   'science',
#   'new',
#   'technology',
#   'catharina',
#   'mitigate',
#   'climate_change',
#   'learn',
#   'make',
#   'big',
#   'leap',
#   'lead',
#   'change'],
#  ['1_billion',
#   'people',
#   'world',
#   'live',
#   'disability',
#   'make',
#   '1_billion',
#   'reason',
#   'build_inclusive',
#   'accessible',
#   'workplace',
#   'and',
#   'world',
#   '🧍🏿',
#   '♀_️',
#   '👩',
#   '🏽🦯',
#   '👨',
#   '🏿🦽join',
#   'us',
#   'nov',
#   '30',
#   'mark',
#   'year',
#   'discussion',
#   'contribution',
#   'person_disability',
#   'our',
#   'workplace',
#   'society',
#   'well',
#   'we',
#   'well',
#   'ally',
#   'speaker',
#   'digital',
#   'creator',
#   'author',
#   'molly',
#   'burke',
#   'motivational',
#   'tedx',
#   'speaker',
#   'happiness',
#   'coach',
#   'sai',
#   'kaustuv',
#   'dasgupta',
#   'host',
#   'our',
#   'global',
#   'inclusion_diversity',
#   'lead',
#   'beck',
#   'baileysave',
#   'date'],
#  ['ready',
#   'watch',
#   'something',
#   'cool',
#   'check',
#   'bt',
#   'we',
#   'create',
#   'cute',
#   'dog',
#   'our',
#   'industry_x',
#   'spot',
#   '💜',
#   '🐶',
#   '😎',
#   'learn'],
#  ['we',
#   'support',
#   'trans',
#   'community',
#   'commit',
#   'further',
#   'equality',
#   'today',
#   'we',
#   'honor',
#   'remember',
#   'trans',
#   'life',
#   'lose',
#   'transphobia',
#   'antitransgender',
#   'violence'],
#  ['we',
#   'celebrate',
#   'positive',
#   'contribution',
#   'man',
#   'bring',
#   'world',
#   'family',
#   'community',
#   'swipe',
#   'learn',
#   'accenture',
#   'man'],
#  ['ai',
#   'achiever',
#   'multitasker',
#   'expertly',
#   'balance',
#   'essential',
#   'capability',
#   'across',
#   'organization',
#   'result',
#   'great',
#   'revenue_growth',
#   'let',
#   'we',
#   'know',
#   'capability',
#   'you',
#   'think',
#   'vital',
#   'ai_maturity',
#   'learn',
#   'you',
#   'join',
#   '12',
#   'company',
#   'achieve',
#   'ai',
#   'goal'],
#  ['growth',
#   'relevance',
#   'begin',
#   'business',
#   'stop',
#   'see',
#   'customer',
#   'start',
#   'see',
#   'people',
#   'end',
#   'see',
#   'future',
#   'hold',
#   'playbook'],
#  ['government',
#   'need',
#   'chase',
#   'digital',
#   'giant',
#   'our',
#   'new',
#   'survey',
#   'show',
#   'refocus',
#   '3',
#   'fundamental',
#   'customer_experience',
#   'deliver',
#   'people',
#   'really',
#   'want'],
#  ['life',
#   'full',
#   'contradiction',
#   'our',
#   'value',
#   'our',
#   'behavior',
#   'always',
#   'go',
#   'together',
#   'call',
#   'company',
#   'center',
#   'strategy',
#   'people',
#   'rather',
#   'customer',
#   'forefront',
#   'listen',
#   'episode',
#   '21'],
#  ['omniconnecte_experience',
#   'level_playing',
#   'field',
#   'everyone',
#   'equitable',
#   'experience',
#   'participate',
#   'fully',
#   'regardless',
#   'location',
#   'find',
#   'build',
#   'strong',
#   'organizational',
#   'culture',
#   'work'],
#  ['like',
#   'her',
#   'great',
#   'aunt',
#   'raquel',
#   'always',
#   'wanted',
#   'become',
#   'engineer',
#   'see',
#   'achieve',
#   'her',
#   'goal',
#   'land',
#   'her',
#   'dream',
#   'role'],
#  ['look',
#   'wing',
#   '🐶',
#   '🤩',
#   '✨',
#   'take',
#   'you',
#   'backstage',
#   'creation',
#   'our',
#   'futuristic',
#   'industry_x',
#   'dog',
#   'see',
#   'we',
#   'help',
#   'client',
#   'digitize',
#   'revolutionize',
#   'product'],
#  ['set',
#   'achiever',
#   'apart',
#   'achieve',
#   '50',
#   'great',
#   'revenue_growth',
#   'learn'],
#  ['lifecentric',
#   'business',
#   'see',
#   'customer',
#   'full',
#   'life',
#   'adapt',
#   'everchange',
#   'needsthe',
#   'old',
#   'customercentric',
#   'playbook',
#   'relevance',
#   'obsolete',
#   'business',
#   'shift',
#   'lifecentric',
#   'strategy',
#   'well',
#   'positioned',
#   'maintain',
#   'relevance',
#   'thrive'],
#  ['our',
#   'commitment',
#   'culture_equality',
#   'shine',
#   'everything',
#   'we',
#   'congratulation',
#   'our',
#   'leader',
#   'recognize',
#   'year',
#   'involve',
#   'inclusion',
#   'people',
#   'outstanding',
#   'lgbt',
#   'role',
#   'model',
#   'list'],
#  ['93',
#   'company',
#   'vow',
#   'reach',
#   'commitment',
#   '2050',
#   'miss',
#   'target',
#   'find',
#   'you',
#   'help',
#   'accelerate',
#   'company',
#   'goal',
#   'combat'],
#  ['do',
#   'right',
#   'create',
#   'unique',
#   'experience',
#   'excite',
#   'consumer',
#   'make',
#   'purchase',
#   'serendipitous',
#   'social',
#   'shopping',
#   'experience',
#   'potential',
#   'transform',
#   'marketplace'],
#  ['our',
#   'christie',
#   'smith',
#   'understand',
#   'power',
#   'strong',
#   'team',
#   'share',
#   'help',
#   'we',
#   'focus',
#   'skill',
#   'allow',
#   'organization',
#   'widen',
#   'pool',
#   'talent',
#   'also',
#   'increase',
#   'equity',
#   'diversity',
#   'inclusion',
#   'wire'],
#  ['good',
#   'artificial',
#   'intelligence',
#   'help',
#   'human',
#   'being',
#   'work_together',
#   '🤗',
#   'discover',
#   'lendlease',
#   'use',
#   'bridge',
#   'gap',
#   'team',
#   'forge',
#   'way',
#   'toward',
#   'well',
#   'efficient',
#   'building',
#   'hear',
#   'story',
#   'episode',
#   '20'],
#  ['sit',
#   'courtside',
#   'nba',
#   'game',
#   'without',
#   'ever',
#   'leave',
#   'living',
#   'room',
#   'technology',
#   'experience',
#   'could',
#   'become',
#   'reality',
#   'espns',
#   'kevin',
#   'lopes',
#   'share',
#   'his',
#   'thought',
#   'exciting',
#   'trend_shape',
#   'future',
#   'industry'],
#  ['samta',
#   'kapoor',
#   'md',
#   'industrial',
#   'cluster',
#   'change',
#   'future',
#   'climate_change',
#   'we',
#   'combine',
#   'automate',
#   'intelligence',
#   'human',
#   'intelligence',
#   'wire'],
#  ['our',
#   'new',
#   'playbook',
#   'show',
#   'organization',
#   'drive',
#   'growth',
#   'use',
#   'technology',
#   'creatively',
#   'solve',
#   'emerge',
#   'customer',
#   'need',
#   'good',
#   'view',
#   'experience',
#   'download',
#   'our',
#   'accenture_foresight',
#   'app',
#   'google',
#   'play',
#   'apple',
#   'app',
#   'store'],
#  ['competitive',
#   'broadcasting',
#   'market',
#   'quality',
#   'content',
#   'matter',
#   'viewer',
#   'experience',
#   'see',
#   'we',
#   'help',
#   'giant',
#   'globo',
#   'optimize',
#   'increase',
#   'engagement',
#   'put',
#   'viewer',
#   'heart',
#   'strategy'],
#  ['we',
#   'honor',
#   'among',
#   'top',
#   'scorer',
#   'workplace',
#   'pride',
#   '2022',
#   'global',
#   'benchmark',
#   '7th',
#   'consecutive_year',
#   'thank_you',
#   'our',
#   'global',
#   'network',
#   '120k',
#   'ally',
#   'make',
#   'possible',
#   'live',
#   'our',
#   'culture_equality',
#   'every_day'],
#  ['new',
#   'founder',
#   'digitallysavvy',
#   'unique',
#   'goal',
#   'priority',
#   'predominantly',
#   'selffunde',
#   'importantly',
#   'theyre',
#   'radically',
#   'change',
#   'landscape'],
#  ['web3',
#   'lay',
#   'foundation',
#   'something',
#   'every',
#   'business',
#   'need',
#   'think',
#   'watch',
#   'full',
#   'discussion',
#   'accenture',
#   'paul_daugherty',
#   'fortunes',
#   'alan',
#   'murray',
#   'learn',
#   'company',
#   'take',
#   'approach',
#   'towards',
#   'transformation'],
#  ['capture',
#   'carbon',
#   'affordable',
#   'housing',
#   'fighting',
#   'food',
#   'waste',
#   'common',
#   '✨',
#   '\U0001fae7',
#   'harness',
#   'power',
#   'change',
#   '\U0001fae7',
#   '✨',
#   'see',
#   'we',
#   'help',
#   'climeworks',
#   'canada',
#   'mortgage',
#   'housing',
#   'corporation',
#   'cmhc',
#   'société',
#   'canadienne',
#   'dhypothèques',
#   'et',
#   'de',
#   'logementschl',
#   'felix',
#   'project',
#   'find',
#   'solution',
#   'create',
#   'great',
#   'impact'],
#  ['selfmilke',
#   'cow',
#   'autonomous',
#   'harvesting',
#   'our',
#   'blog',
#   'explain',
#   'help',
#   'farmer',
#   'work',
#   'smarter',
#   'get',
#   'return'],
#  ['digital',
#   'world',
#   'you',
#   'create',
#   'connect',
#   'flourish',
#   'possible',
#   '🎙',
#   'hear',
#   'we',
#   'late',
#   'episode'],
#  ['quantum',
#   'hpc',
#   'biologyinspired',
#   'machine',
#   'new',
#   'suite',
#   'tool',
#   'unique',
#   'demand',
#   'postdigital',
#   'business',
#   'discover'],
#  ['give',
#   'we',
#   'insight',
#   'make',
#   'well',
#   'decision',
#   'improve',
#   'worker',
#   'safety',
#   'drive',
#   'exponential',
#   'growth',
#   'business',
#   'see',
#   'deliver',
#   'value',
#   'our',
#   'life',
#   'work',
#   'three',
#   'different',
#   'perspective',
#   'include',
#   'our',
#   'lan',
#   'guan',
#   'wire'],
#  ['we',
#   'move',
#   'towards',
#   'truly',
#   'seamless',
#   'digital',
#   'experience',
#   'organization',
#   'need',
#   'rethink',
#   'way',
#   'leverage',
#   'datum',
#   'digital',
#   'platform',
#   '2022',
#   'explain'],
#  ['our',
#   'partnership',
#   'intel',
#   'corporation',
#   'optimize',
#   'technology',
#   'create',
#   'value',
#   'our',
#   'client',
#   'together',
#   'we',
#   'provide',
#   'right',
#   'people',
#   'right',
#   'expertise',
#   'drive',
#   'and',
#   'transformation'],
#  ['dream',
#   'job',
#   'connect',
#   'professional',
#   'impact',
#   'personal',
#   'value',
#   '🎉',
#   '\U0001fae7',
#   'bingo',
#   '🎉',
#   '\U0001fae7',
#   'sign',
#   'you',
#   'wait'],
#  ['benefit',
#   'go',
#   'far',
#   'beyond',
#   'financial',
#   'cloud',
#   'spark',
#   'new',
#   'wave',
#   'innovation',
#   'industry',
#   'application',
#   'endless',
#   'think',
#   'possibility',
#   'within',
#   'aerospace'],
#  ['grow',
#   'get',
#   'tough',
#   'tough',
#   'get',
#   'playbook',
#   '💁',
#   'read',
#   'company',
#   'shift',
#   'productcentric',
#   'customercentric',
#   'strategy',
#   'become',
#   'lifecentric',
#   'well',
#   'positioned',
#   'maintain',
#   'relevance',
#   'thrive'],
#  ['accelerate',
#   'product',
#   'innovation',
#   'value',
#   'clear',
#   'high',
#   'tech',
#   'company',
#   'provider',
#   'consumer',
#   'enabler',
#   'cloud',
#   'one',
#   'cloud',
#   'potential',
#   'even',
#   'great'],
#  ['industry',
#   'like',
#   'defense',
#   'room',
#   'error',
#   'security',
#   'concern',
#   'ease',
#   'aerospace',
#   'defense',
#   'organization',
#   'realize',
#   'enhance',
#   'one',
#   'many',
#   'advantage',
#   'cloudenable',
#   'future'],
#  ['we',
#   'speak',
#   '10yearold',
#   'artist',
#   'computer',
#   'science',
#   'student',
#   'our',
#   'expert',
#   'sanjeev',
#   'vohra',
#   'impact',
#   'our',
#   'everyday',
#   'life',
#   'watch',
#   'say',
#   'wire'],
#  ['we',
#   'move',
#   'towards',
#   'truly',
#   'seamless',
#   'digital',
#   'experience',
#   'organization',
#   'need',
#   'rethink',
#   'way',
#   'leverage',
#   'datum',
#   'digital',
#   'platform',
#   '2022',
#   'explain'],
#  ['dream',
#   'job',
#   'connect',
#   'professional',
#   'impact',
#   'personal',
#   'value',
#   '🎉',
#   '\U0001fae7',
#   'bingo',
#   '🎉',
#   '\U0001fae7',
#   'sign',
#   'you',
#   'wait'],
#  ['oh',
#   'amazing',
#   'people',
#   'place',
#   'accenture',
#   'you',
#   'work',
#   'possibility',
#   'endless',
#   'honor',
#   'name',
#   'one',
#   'world',
#   'good_workplace',
#   '™',
#   'fortune_magazine',
#   'great_place',
#   'work',
#   'see',
#   'impact',
#   'our',
#   'people',
#   'great_place',
#   'work',
#   'we'],
#  ['we',
#   'team',
#   'meta',
#   'microsoft',
#   'help',
#   'company',
#   'create',
#   'new',
#   'experience',
#   'metaverse',
#   'interact',
#   'people',
#   'customer',
#   'make',
#   'distribute',
#   'product_service',
#   'possibility',
#   'endless',
#   'I',
#   'can_not',
#   'wait',
#   'see',
#   'our',
#   'collaboration',
#   'change',
#   'landscape'],
#  ['we',
#   'sit',
#   'work',
#   'futurist',
#   'founder',
#   'ceo',
#   'global',
#   'talent',
#   'lead',
#   'hear',
#   'say',
#   'episode',
#   '18',
#   'podcast'],
#  ['we',
#   'celebrate',
#   'our',
#   'lgbtiq',
#   'community',
#   'share',
#   'tip',
#   'you',
#   'ally',
#   'create',
#   'environment',
#   'people',
#   'themselves'],
#  ['explain',
#   'term',
#   'everyone',
#   'understand',
#   'our',
#   'new',
#   'series',
#   'wire',
#   'we',
#   'explore',
#   'ai',
#   'impact',
#   'our',
#   'everyday',
#   'life',
#   'business',
#   'planet',
#   'three',
#   'perspective',
#   'a',
#   'child',
#   'college',
#   'student',
#   'one',
#   'our',
#   'expert'],
#  ['ok',
#   'ok',
#   'committed',
#   'break',
#   'stigma',
#   'mental',
#   'health',
#   'wellness',
#   'dr',
#   'tamarah',
#   'dupervalbrownlee',
#   'md',
#   'mph',
#   'mba',
#   'faafp',
#   'our',
#   'chief',
#   'health',
#   'officer',
#   'explain',
#   'we',
#   'make',
#   'dimension',
#   'health',
#   'priority',
#   'physical',
#   'emotional',
#   'mental',
#   'social',
#   'learn'],
#  ['inspire',
#   'childhood',
#   'dream',
#   'build',
#   'world',
#   'dheeraj',
#   'designing',
#   'innovation',
#   'auto',
#   'aviation',
#   'industry'],
#  ['synthetic',
#   'realness',
#   'evolve',
#   'well',
#   'consider',
#   'what_s',
#   'real',
#   'what_s',
#   'importantly',
#   'matter'],
#  ['legacy',
#   'mindset',
#   'hold',
#   'you',
#   'back',
#   'keep',
#   'change',
#   'consumer',
#   'habit',
#   'focus',
#   '12',
#   'characteristic',
#   'future',
#   'ready'],
#  ['ai',
#   'achiever',
#   'multitasker',
#   'expertly',
#   'balance',
#   'essential',
#   'capability',
#   'across',
#   'organization',
#   'result',
#   'great',
#   'revenue_growth',
#   'let',
#   'we',
#   'know',
#   'capability',
#   'you',
#   'think',
#   'vital',
#   'ai_maturity',
#   'learn',
#   'you',
#   'join',
#   '12',
#   'company',
#   'achieve',
#   'ai',
#   'goal'],
#  ['congratulation',
#   'our',
#   'chair',
#   'ceo_julie',
#   'sweet_recognize',
#   'fortune_magazine',
#   'powerful_woman',
#   'list',
#   'our',
#   'people',
#   'client',
#   'community',
#   'inspire',
#   'impact',
#   'you',
#   'make',
#   'value',
#   'you',
#   'help',
#   'we',
#   'create',
#   'every_direction',
#   'every',
#   'single',
#   'day'],
#  ['consumer',
#   'preference',
#   'always',
#   'change',
#   'brand',
#   'need',
#   'ready',
#   'adapt',
#   'grow',
#   'read',
#   'our',
#   'future',
#   'ready',
#   'report',
#   'learn'],
#  ['we',
#   'get',
#   'time',
#   'precious',
#   'we',
#   'develop',
#   'accenture_foresight',
#   'our',
#   'onestop',
#   'app',
#   'business',
#   'technology',
#   'insight',
#   'direct',
#   'our',
#   'lead',
#   'thinker',
#   'phone',
#   'download',
#   'free'],
#  ['leader',
#   'indigo',
#   'wants',
#   'save',
#   'farm',
#   'and',
#   'planet',
#   'start',
#   'soil',
#   'get',
#   'full',
#   'story',
#   'our',
#   'podcast'],
#  ['swipe',
#   'see',
#   'old',
#   'customercentric',
#   'playbook',
#   'relevance',
#   'obsolete'],
#  ['happy',
#   '🎧',
#   'look',
#   'something',
#   'new',
#   'listen',
#   'tune',
#   'adweek',
#   '2021',
#   'think',
#   'leadership',
#   'podcast',
#   'year'],
#  ['🚨',
#   'icymi',
#   'our',
#   'martha',
#   'cotton',
#   'mark',
#   'curtis',
#   'share',
#   'time',
#   'redesign',
#   'pretty',
#   'much',
#   'everythingjoin',
#   'we',
#   'we',
#   'explore',
#   'happen',
#   'next',
#   'from',
#   'end',
#   'abundance',
#   'thinking',
#   'rise',
#   'new',
#   'set',
#   'iconic',
#   'hero',
#   'focus',
#   'regeneration'],
#  ['diverse',
#   'inclusive',
#   'innovative',
#   'well',
#   'way',
#   'celebrate',
#   'our',
#   'people',
#   'and',
#   '721000',
#   'amazing',
#   'incredible',
#   'contribution',
#   'share',
#   'success',
#   'our',
#   'company',
#   'our',
#   'client',
#   'our',
#   'community',
#   'than',
#   'rank',
#   'top',
#   'refinitiv',
#   'lseg',
#   'business',
#   'global',
#   'diversity',
#   'inclusion',
#   'index'],
#  ['congratulation',
#   'year',
#   'sustainability',
#   'innovation',
#   'challenge',
#   'winner',
#   '🎉',
#   'future',
#   'food',
#   'climate',
#   'action',
#   'education',
#   'we',
#   'help',
#   'make',
#   'future',
#   'sustainable',
#   '🌎',
#   '💜',
#   'learn',
#   'win',
#   'idea'],
#  ['stay',
#   'ahead',
#   'change',
#   'accenture_foresight',
#   'our',
#   'new',
#   'thought',
#   'leadership',
#   'app',
#   'insightful',
#   'perspective',
#   'business',
#   'technology',
#   'trend',
#   'download'],
#  ['science',
#   'tell',
#   'we',
#   'repetition',
#   'good',
#   'way',
#   'overcome',
#   'speech',
#   'sound',
#   'disorder',
#   'also',
#   'tell',
#   'we',
#   'child',
#   'fluent',
#   'song',
#   'speech',
#   'well',
#   'way',
#   'practice',
#   'repetition',
#   'song',
#   'together',
#   'warner',
#   'music',
#   'group',
#   'apple',
#   'music',
#   'we',
#   'analyze',
#   '70',
#   'million',
#   'song',
#   'find',
#   'one',
#   'therapeutic',
#   'value',
#   'carefully',
#   'curate',
#   'playlist',
#   'tailor',
#   'certain',
#   'syllable',
#   'pattern',
#   'sound',
#   'make',
#   'speech',
#   'therapy',
#   'fun',
#   'help',
#   'everyone',
#   'find',
#   'unique',
#   'voice'],
#  ['our',
#   'chair',
#   'ceo_julie',
#   'sweet',
#   'meet',
#   'sandeep',
#   'dadlani',
#   'discuss',
#   'our',
#   'partnership',
#   'help',
#   'mars',
#   'catapult',
#   'digitalfirst',
#   'industry',
#   'leader',
#   'compress',
#   'transformation',
#   'cybersecurity',
#   'drive',
#   'inclusion_diversity',
#   'equity',
#   'organization',
#   'hear',
#   'whole',
#   'conversation'],
#  ['always',
#   'proud',
#   'play',
#   'part',
#   'bring',
#   'global',
#   'citizen',
#   'life',
#   'learn',
#   'work',
#   'we',
#   'impact',
#   'we',
#   'create'],
#  ['our',
#   'shirt',
#   'reveal',
#   'we',
#   'want',
#   'hear',
#   'you',
#   'which',
#   'favorite',
#   'check',
#   'our',
#   'profile',
#   'see',
#   '🤗',
#   '💜'],
#  ['proud',
#   'continue',
#   'our',
#   'partnership',
#   'global',
#   'citizen',
#   '💜',
#   '🌍',
#   'year',
#   'we',
#   'design',
#   'limited',
#   'collection',
#   'tshirt',
#   'represent',
#   'impactful',
#   'story',
#   'our',
#   'story',
#   'change',
#   'swipe',
#   'see',
#   'collection',
#   'learn',
#   'we',
#   'make',
#   'positive',
#   'global',
#   'impact'],
#  ['company',
#   'need_strengthen',
#   'dna',
#   'deliver',
#   'value',
#   'impact_stakeholder',
#   'organization',
#   'shape',
#   'find',
#   'our',
#   'diagnostic'],
#  ['come',
#   'soon',
#   'the',
#   'world',
#   'tour',
#   '🌏',
#   'be',
#   'sure',
#   'follow',
#   'we',
#   'instagram',
#   'detail',
#   '🎶',
#   '🎤'],
#  ['43',
#   'consumer',
#   'say',
#   'technology',
#   'advance',
#   'complicated',
#   'life',
#   'much',
#   'simplify',
#   'thingsis',
#   'technology',
#   'simplify',
#   'complicate',
#   'customer',
#   'live'],
#  ['you',
#   'confident',
#   'you',
#   'could',
#   'recognize',
#   'deepfake',
#   'synthetic',
#   'content',
#   'time',
#   'will',
#   'not',
#   'matter',
#   'help',
#   'organization',
#   'prepare',
#   'time'],
#  ['quantum',
#   'computing',
#   'lead',
#   'carl',
#   'lay',
#   'foundation',
#   'become',
#   'one',
#   'disruptive',
#   'transformative',
#   'technology',
#   'time',
#   'discover',
#   'his',
#   'career',
#   'journey',
#   'inspire',
#   'join',
#   'our',
#   'team',
#   'designer',
#   'creator',
#   'strategist'],
#  ['remember',
#   'our',
#   'futuristic',
#   'robot',
#   'our',
#   'industry_x',
#   'spot',
#   'watch',
#   'design',
#   'process',
#   'come',
#   '🦾',
#   '👏',
#   '💜',
#   'more',
#   'we',
#   'help',
#   'our',
#   'client',
#   'reimagine',
#   'product',
#   'make',
#   'make'],
#  ['datum',
#   'tech',
#   'driver',
#   'incredible',
#   'change',
#   'ever_wonder',
#   'can',
#   '🌏',
#   'change',
#   'course',
#   'climate_change',
#   '🏡',
#   'create',
#   'affordable',
#   'housing',
#   'all',
#   '🌽',
#   'end',
#   'hunger',
#   'crisis',
#   'eliminate',
#   'food',
#   'wastecurious',
#   'hear',
#   'story'],
#  ['tired',
#   'use',
#   'ai',
#   'technology',
#   'make',
#   'deepfake',
#   'wire',
#   'use',
#   'deepfake',
#   'technology',
#   'make',
#   'art',
#   'write',
#   'podcast',
#   'design',
#   'episode',
#   'our',
#   'podcast',
#   'you',
#   'look',
#   'deepfake',
#   'whole',
#   'new',
#   'light'],
#  ['company',
#   'new',
#   'steward',
#   'planet',
#   'thank',
#   'financial',
#   'incentive',
#   'come',
#   'pursue',
#   'decarbonization',
#   'industry',
#   'may',
#   'big',
#   'part',
#   'solution'],
#  ['celebrate',
#   'our',
#   'yahoo',
#   'finance',
#   'lead_way',
#   'champion',
#   'woman',
#   'business',
#   'driving',
#   'change',
#   'gender',
#   'diversity',
#   'demonstrate',
#   'incredible',
#   'impact',
#   'achieve',
#   'we',
#   'work_together',
#   'accelerate',
#   'equality'],
#  ['you_know',
#   'our',
#   'annual_report',
#   'guide',
#   'business',
#   'adapt',
#   'what_s',
#   'next'],
#  ['eu',
#   'green',
#   'deal',
#   'call',
#   'greenhouse',
#   'gas',
#   'emission',
#   '2050',
#   'the',
#   'ultimate',
#   'challenge',
#   'industry',
#   'hard',
#   'work',
#   'investment',
#   'pay'],
#  ['meet',
#   'eu',
#   'green',
#   'deal',
#   'goal',
#   'create',
#   'europe',
#   '2050',
#   'could',
#   'cost',
#   'industry',
#   'estimate',
#   '€',
#   '1',
#   'trillion',
#   'despite',
#   'hefty',
#   'price',
#   'tag',
#   'growth',
#   'opportunity',
#   'priceless'],
#  ['🍹',
#   '🍸',
#   '🍹',
#   'cocktail',
#   'home',
#   'push',
#   'button',
#   'possible',
#   'thank',
#   'our',
#   'business',
#   'strategist',
#   'kiara',
#   'discover',
#   'her',
#   'exciting',
#   'career',
#   'join_we'],
#  ['miner', 'lead', 'charge', 'decarbonization', 'find', 'behind', 'focus'],
#  ['we',
#   'know',
#   'cloudbase',
#   'software',
#   'cloudbase',
#   'storage',
#   'cloudbase',
#   'brewing',
#   'thing',
#   'and',
#   'could',
#   'secret',
#   'perfect',
#   'pint',
#   'our',
#   'podcast'],
#  ['strategy',
#   '➕',
#   'purpose',
#   'win',
#   'combination',
#   '🤗',
#   '💜',
#   'peek',
#   'our',
#   'business',
#   'value',
#   'and',
#   'progress',
#   'we_ve',
#   'make',
#   'create_inclusive',
#   'sustainable_future'],
#  ['harness',
#   'imagination',
#   'technology',
#   'help',
#   'take',
#   'dheeraj',
#   'his',
#   'team',
#   'forefront',
#   'aircraft',
#   'auto',
#   'industry',
#   'learn'],
#  ['rise',
#   'create',
#   'major',
#   'implication',
#   'industry',
#   'here',
#   'automaker',
#   'prepare',
#   'electrification',
#   'era'],
#  ['20yearold',
#   'playbook',
#   'achieve',
#   'relevance',
#   'growth',
#   'customer',
#   'centricity',
#   'be',
#   'long',
#   'enoughcompanie',
#   'must',
#   'evolve',
#   'focus',
#   'consumption',
#   'contribution',
#   'customercentric',
#   'lifecentric',
#   'view',
#   'read',
#   'our',
#   'new_report'],
#  ['excited',
#   'partner',
#   'save',
#   'child',
#   'we',
#   'through',
#   'our',
#   'new',
#   'grant',
#   'we',
#   'skille',
#   'support',
#   'estimate',
#   '70000',
#   'young',
#   'people',
#   'successful',
#   'future',
#   'work',
#   'green',
#   'economy',
#   'together',
#   'we',
#   'aim',
#   'create',
#   'sustainable_future'],
#  ['consumer',
#   'crave',
#   'and',
#   'expect',
#   'modernized',
#   'experience',
#   'ability',
#   'buy',
#   'car',
#   'comfort',
#   'home',
#   'consumer',
#   'long',
#   'satisfy',
#   'traditional',
#   'buying',
#   'experience'],
#  ['move',
#   'fast',
#   'break',
#   'thing',
#   'nearuniversal',
#   'mantra',
#   'tech',
#   'industry',
#   'founder',
#   'starting',
#   'run',
#   'thing',
#   'differently',
#   'episode',
#   'we',
#   'share',
#   'put',
#   'ethic',
#   'first',
#   'help',
#   'company',
#   'innovate',
#   'fast',
#   'ever'],
#  ['learn',
#   'accenture',
#   'harness',
#   'power',
#   'datum',
#   'deliver',
#   'new',
#   'insight',
#   'our',
#   'business',
#   'efficiently'],
#  ['whether',
#   'patient',
#   'provider',
#   'locationflexible',
#   'make',
#   'care',
#   'easier',
#   'put',
#   'human',
#   'first'],
#  ['proud',
#   'partner',
#   'southern',
#   'company',
#   'cocacola',
#   'company',
#   'tour',
#   'championship',
#   'sponsor'],
#  ['🌍',
#   'hear',
#   'help',
#   'climeworks',
#   'scale',
#   'technology',
#   'and',
#   'speed',
#   'effort',
#   'remove',
#   'carbon',
#   'atmosphere'],
#  ['together',
#   'we',
#   'make_difference',
#   'we',
#   'proud',
#   'partner',
#   'tour',
#   'championship',
#   'organization',
#   'like',
#   'first',
#   'tee',
#   'metro',
#   'atlanta',
#   'east',
#   'lake',
#   'foundation',
#   'make_difference',
#   'our',
#   'community'],
#  ['next_decade',
#   'critical',
#   'transition',
#   'towards',
#   'sustainability',
#   '5_key',
#   'takeaway',
#   'consider',
#   'race'],
#  ['we', 'bring', 'change', 'business', 'help', 'business', 'change', 'world'],
#  ['thrilled',
#   'sponsor',
# ...
#   'result',
#   'strong',
#   'growth'],
#  ['need',
#   'well',
#   'sustainability',
#   'business',
#   'grow',
#   'play',
#   'vital',
#   'role',
#   'help',
#   'company',
#   'green'],
#  ['human',
#   'focus',
#   'essential',
#   'season',
#   'retailer',
#   'need',
#   'demonstrate',
#   'genuine',
#   'commitment',
#   'responsibility',
#   'especially',
#   'employee',
#   'explore',
#   'our',
#   'holiday',
#   '2020',
#   'research'],
#  ['move',
#   'cloud',
#   '☁',
#   '️',
#   'people',
#   'know',
#   'watch',
#   'new',
#   'life',
#   'come',
#   'business'],
#  ['focus',
#   'accelerate',
#   'digital_transformation',
#   'across',
#   'enterprise',
#   'and',
#   'honor',
#   'name',
#   'leader',
#   'digital',
#   'business',
#   'transformation',
#   'service',
#   'forrester',
#   '2020',
#   'assessment'],
#  ['organization',
#   'seize',
#   'opportunity',
#   'reset',
#   'tech',
#   'culture',
#   'our',
#   'paul_daugherty',
#   'share',
#   'business',
#   'create_inclusive',
#   'culture',
#   'our',
#   'late',
#   'research',
#   'girl',
#   'code'],
#  ['we',
#   'work',
#   'nhs',
#   'digital',
#   'rapidly',
#   'implement',
#   'communication',
#   'platform',
#   'connect',
#   '12',
#   'million',
#   'worker',
#   'across',
#   '16000',
#   'nhs',
#   'organization',
#   'here'],
#  ['everything',
#   'we',
#   'thank',
#   'every',
#   'one',
#   'our',
#   'amazing',
#   'people',
#   '👩',
#   '🏽',
#   '🦱',
#   '🧔',
#   '🏻',
#   '👨',
#   '🏼',
#   '🦰',
#   '🧑',
#   '🧑',
#   '🏻',
#   '👨',
#   '🏾',
#   '👩',
#   '🏼',
#   '👨',
#   '🏽',
#   '🦲',
#   '💜',
#   'thank',
#   'helping',
#   'celebrate',
#   'our',
#   'new',
#   'brand'],
#  ['despite',
#   'year',
#   'investment',
#   'company',
#   'be_not',
#   'get',
#   'full',
#   'benefit',
#   'that',
#   'and',
#   'fix'],
#  ['visionary',
#   'icon',
#   'business',
#   'politic',
#   'culture',
#   'explore',
#   'today',
#   'pivotal',
#   'question',
#   'excited',
#   'sponsor',
#   'nytime',
#   'online',
#   'summit',
#   'nov',
#   '1718',
#   'join_we'],
#  ['☁',
#   '️',
#   '🌳',
#   '🌍',
#   'cloud',
#   'system',
#   'design',
#   'business',
#   'planet',
#   'mind',
#   'see',
#   'what_s',
#   'possible'],
#  ['unpatched',
#   'untested',
#   'device',
#   'leave',
#   'critical',
#   'system',
#   'expose',
#   'learn',
#   'attacker',
#   'find',
#   'new',
#   'way',
#   'exploit',
#   'device'],
#  ['company',
#   'scale',
#   'get',
#   '3x',
#   'roi',
#   'learn',
#   'four',
#   'key',
#   'step',
#   'professionalization',
#   'make',
#   'you',
#   'strategic',
#   'scaler'],
#  ['board',
#   'involve',
#   'workforce',
#   'strategy',
#   'well',
#   'prepared',
#   'deal',
#   'company',
#   'crises—16x',
#   'well',
#   'fact',
#   'find',
#   'take',
#   'become',
#   'modern',
#   'board'],
#  ['migration',
#   'create',
#   'equal',
#   'focus',
#   '3',
#   'area',
#   'drive',
#   'find',
#   'green',
#   'behind',
#   'cloud',
#   '✅',
#   'select',
#   'purpose',
#   '✅',
#   'build',
#   'ambition',
#   '✅',
#   'innovate'],
#  ['our',
#   'late',
#   'research',
#   'uncover',
#   '5',
#   'employer',
#   'practice',
#   'take',
#   'together',
#   'form',
#   'sweet',
#   'spot',
#   'investment',
#   'pay',
#   'dividend',
#   'individual',
#   'organization'],
#  ['we',
#   'know',
#   'sustainability',
#   'heart',
#   'business',
#   'we',
#   'get',
#   'you',
#   'you',
#   'get',
#   'close',
#   'sustainability',
#   'goal',
#   'all',
#   'without',
#   'miss',
#   'beat'],
#  ['our',
#   '2020',
#   'cyber',
#   'report',
#   'here',
#   'read',
#   '5',
#   'big',
#   'factor',
#   'influence',
#   'landscape',
#   'right'],
#  ['everything',
#   'we',
#   'thank',
#   'every',
#   'one',
#   'our',
#   'amazing',
#   'people',
#   '👩',
#   '🏽',
#   '🦱',
#   '🧔',
#   '🏻',
#   '👨',
#   '🏼',
#   '🦰',
#   '🧑',
#   '🧑',
#   '🏻',
#   '👨',
#   '🏾',
#   '👩',
#   '🏼',
#   '👨',
#   '🏽',
#   '🦲',
#   '💜',
#   'thank',
#   'helping',
#   'celebrate',
#   'our',
#   'new',
#   'brand'],
#  ['proud',
#   'recognize',
#   'inaugural',
#   'glassdoor',
#   'mit',
#   'sloan',
#   'management',
#   'review',
#   '2020',
#   'list',
#   'our',
#   'people',
#   'make',
#   'our',
#   'culture',
#   'thank_you',
#   'help',
#   'we',
#   'achieve',
#   'honor'],
#  ['pressure',
#   'board',
#   'engagement',
#   'workforce',
#   'strategy',
#   'long',
#   'option',
#   'new',
#   'oversight',
#   'find',
#   'take',
#   'become',
#   'modern',
#   'board',
#   'our',
#   'new_report'],
#  ['we',
#   'harness',
#   'technology',
#   'human_ingenuity',
#   'help',
#   'make',
#   'change',
#   'work',
#   'you'],
#  ['wherever',
#   'business',
#   'go',
#   'you',
#   'need',
#   'cybersecurity',
#   'cover',
#   'see',
#   'we',
#   'help'],
#  ['hail',
#   'her',
#   'vision',
#   'influence',
#   'steady',
#   'leadership',
#   'uncertain',
#   'time',
#   'we',
#   'proud',
#   'our',
#   'ceo_julie',
#   'sweet_recognize',
#   'fortune',
#   'business',
#   'list',
#   'congrats',
#   'julie'],
#  ['move',
#   'cloud',
#   'people',
#   'know',
#   'watch',
#   'new',
#   'life',
#   'come',
#   'business'],
#  ['everything',
#   'we',
#   'thank',
#   'every',
#   'one',
#   'our',
#   'incredible_people',
#   '👨',
#   '🏾',
#   '👩',
#   '🏼',
#   '👨',
#   '🏼',
#   '🦰',
#   '👩',
#   '🏽',
#   '🦱',
#   '🧑',
#   '🏻',
#   '🦰',
#   '🧔',
#   '🏻',
#   'come',
#   'join_we'],
#  ['change',
#   'around',
#   'we',
#   'whether',
#   'seismic',
#   'small',
#   'we',
#   'make',
#   'work',
#   'you',
#   'business'],
#  ['we',
#   'connect',
#   'small',
#   'business',
#   'owner',
#   'financial',
#   'advisor',
#   'detroit',
#   'pandemic',
#   'volunteer',
#   'exchange',
#   'program',
#   'read',
#   'our',
#   'work',
#   'community'],
#  ['we',
#   'partner',
#   'alibaba',
#   'lead',
#   'chinabased',
#   'retailer',
#   'transform',
#   'business',
#   'use',
#   'power',
#   'fully',
#   'engage',
#   'modern',
#   'customer'],
#  ['accenture',
#   'announce',
#   'new',
#   'commitment',
#   'sustainability',
#   'include',
#   'industryleade',
#   'goal',
#   'netzero',
#   'emission',
#   'well',
#   'newly',
#   'create',
#   'leadership',
#   'role',
#   'peter',
#   'lacy',
#   'appoint',
#   'our',
#   'chief',
#   'responsibility',
#   'officer',
#   'global',
#   'sustainability',
#   'service',
#   'lead',
#   'effective',
#   'december',
#   '1',
#   'hell',
#   'oversee',
#   'integration',
#   'sustainability',
#   'responsibility',
#   'stakeholder',
#   'our',
#   'client',
#   'service',
#   'well',
#   'our',
#   'operation',
#   'today',
#   'rapid',
#   'acceleration',
#   'digital',
#   'present',
#   'we',
#   'breakthrough',
#   'opportunity',
#   'create',
#   'sustainable_future',
#   'scaling',
#   'ambition',
#   'we',
#   'help',
#   'make',
#   'real',
#   'change',
#   'deliver',
#   '360degree',
#   'value'],
#  ['35',
#   'cxos',
#   'say',
#   'feel',
#   'responsible',
#   'leave',
#   'people',
#   'well',
#   'jump',
#   '50',
#   'but',
#   'still',
#   'fall',
#   'short',
#   'employee',
#   'expectation'],
#  ['fundaula',
#   'our',
#   'elearne',
#   'platform',
#   'help',
#   'user',
#   'develop',
#   'important',
#   'skill',
#   'current',
#   'job',
#   'market',
#   'see',
#   'we_ve',
#   'work',
#   'community',
#   'pandemic'],
#  ['we',
#   'look',
#   'forward',
#   'welcome',
#   'myrtle',
#   'consulting',
#   'group',
#   'accenture',
#   'family'],
#  ['for',
#   'probably',
#   'next',
#   'six',
#   'month',
#   'people',
#   'going',
#   'continue',
#   'live',
#   'office',
#   'our',
#   'ceo',
#   'na',
#   'jimmy',
#   'etheredge',
#   'top',
#   'leader',
#   'pandemic',
#   'impact',
#   'workplace'],
#  ['today',
#   'our',
#   'ellyn_shake',
#   'recognize',
#   'hr',
#   'executive',
#   'magazine',
#   'hr',
#   'executive',
#   'year',
#   'award',
#   'recognize',
#   'many',
#   'contribution',
#   'ellyn',
#   'make',
#   'help',
#   'our',
#   'half',
#   'million',
#   'people',
#   'successful',
#   'professionally',
#   'personally',
#   'congrat',
#   'ellyn'],
#  ['we',
#   'work',
#   'brac',
#   'planning',
#   'mitigate',
#   'risk',
#   'read',
#   'our',
#   'work',
#   'community',
#   'client',
#   'pandemic'],
#  ['across',
#   'accenture',
#   'we',
#   'continue',
#   'take',
#   'action',
#   'racism',
#   'inequality',
#   'note',
#   'I',
#   'send',
#   'today',
#   'accenture',
#   'people',
#   'announce',
#   'our',
#   'new',
#   'goal',
#   'increase',
#   'representation',
#   'our',
#   'african',
#   'black',
#   'coloured',
#   'colleague',
#   'south',
#   'africa',
#   'our',
#   'black',
#   'colleague',
#   'uk',
#   '2025',
#   'well',
#   'our',
#   'mandatory',
#   'training',
#   'identify',
#   'speak',
#   'racism',
#   'we',
#   'believe',
#   'goal',
#   'help',
#   'make',
#   'accenture',
#   'inclusive',
#   'diverse',
#   'representative',
#   'community',
#   'our',
#   'people',
#   'live',
#   'work_together',
#   'we',
#   'act',
#   'we',
#   'lead',
#   'we',
#   'continue',
#   'drive',
#   'change'],
#  ['together',
#   'we',
#   'create',
#   'bright',
#   'future',
#   'excited',
#   'official',
#   'premier',
#   'partner',
#   'expo',
#   '2020',
#   'dubai',
#   'support',
#   'mission',
#   'inspire',
#   'solution',
#   'enable',
#   'action',
#   'towards',
#   'world',
#   'press',
#   'issue'],
#  ['drive',
#   'financial',
#   'security',
#   'agility',
#   'benefit',
#   'you_know',
#   'also',
#   'help',
#   'company',
#   'create_green',
#   'planet',
#   'green',
#   'balance',
#   'sheet',
#   'find'],
#  ['incredible',
#   'work',
#   'bring',
#   'people',
#   'work_connect',
#   'initiative',
#   'life',
#   'early',
#   'day',
#   'pandemic',
#   'we',
#   'proud',
#   'present',
#   'christy',
#   'pambianchi',
#   'verizon',
#   'pat',
#   'wador',
#   'servicenow',
#   'lisa',
#   'buckingham',
#   'lincoln',
#   'financial',
#   'ellyn_shake',
#   'accenture',
#   'our',
#   'innovation',
#   'hr',
#   'award'],
#  ['let',
#   'make',
#   'sure',
#   'woman',
#   'and',
#   'we',
#   'be',
#   'ready',
#   'thrive',
#   'techdriven',
#   'future',
#   'we',
#   'partner',
#   'girl',
#   'code',
#   'uncover',
#   'company',
#   'create_inclusive',
#   'culture',
#   'read',
#   'blog',
#   'see',
#   'leader',
#   'take',
#   'opportunity',
#   'reset',
#   'company',
#   'culture'],
#  ['challenging',
#   'time',
#   'chros',
#   'return',
#   'fundamental',
#   'mission',
#   'care',
#   'worker',
#   'build',
#   'trust',
#   'across',
#   'organization'],
#  ['our',
#   'q4',
#   'fy20',
#   'result',
#   'demonstrate',
#   'our',
#   'relevance',
#   'resilience',
#   'our',
#   'ability',
#   'pivot',
#   'rapidly',
#   'power',
#   'our',
#   'relationship',
#   'world',
#   'lead',
#   'company',
#   'ecosystem',
#   'partner',
#   'our',
#   'commitment',
#   'responsible',
#   'business',
#   'thank',
#   'our',
#   'people',
#   'always'],
#  ['even',
#   'uncertain',
#   'time',
#   'company',
#   'work',
#   'take',
#   'care',
#   'people',
#   'leave',
#   'well',
#   'boost',
#   'business',
#   'performance'],
#  ['drive',
#   'financial',
#   'security',
#   'agility',
#   'benefit',
#   'you_know',
#   'also',
#   'help',
#   'company',
#   'create_green',
#   'planet',
#   'green',
#   'balance',
#   'sheet',
#   'find'],
#  ['we',
#   'nearly',
#   '100000',
#   'professional',
#   'understand',
#   'make',
#   'business',
#   'tick'],
#  ['announce',
#   'accenture',
#   'cloud',
#   'first',
#   'new',
#   'team',
#   '70000',
#   'back',
#   '3b',
#   'investment',
#   'bring',
#   'our',
#   'client',
#   'full',
#   'set',
#   'capability',
#   'need',
#   'become',
#   'cloud',
#   'leader',
#   'speed',
#   'scale',
#   'we',
#   'take',
#   'big',
#   'step',
#   'since',
#   'we',
#   'inflection',
#   'point',
#   'company',
#   'need',
#   'power',
#   'cloud',
#   'complete',
#   'digital_transformation',
#   'covid',
#   'accelerate',
#   'need',
#   'compressed',
#   'timeline',
#   'hence',
#   'company',
#   'move',
#   '20',
#   'cloud',
#   '80',
#   'next',
#   'several',
#   'yearscongrat',
#   'our',
#   'karthik',
#   'narain',
#   'leader',
#   'accenture',
#   'cloud',
#   'first'],
#  ['we',
#   'work',
#   'microsoft',
#   'create',
#   'aidriven',
#   'crisis',
#   'communication',
#   'channel',
#   'help',
#   'bridge',
#   'governmentcitizen',
#   'information',
#   'gap',
#   'read'],
#  ['get',
#   'people',
#   'back',
#   'work',
#   'pandemic',
#   'economy',
#   'that',
#   'goal',
#   'people',
#   'work_connect',
#   'platform',
#   'watch',
#   'learn'],
#  ['30000',
#   'project',
#   'nearly',
#   'every',
#   'industry',
#   'we',
#   'help',
#   'you',
#   'move',
#   'cloud',
#   'without',
#   'miss',
#   'beat'],
#  ['accenture', 'host', 'people', 'work_connect', 'live', 'roundtable', 'rsvp'],
#  ['capture',
#   'full',
#   'value',
#   'require',
#   '5_key',
#   'element',
#   'our',
#   'new',
#   'research',
#   'explain'],
#  ['people',
#   'work_connect',
#   'platform',
#   'help',
#   'company',
#   'fill',
#   'job',
#   'join_we',
#   'live',
#   'discussion',
#   'hr',
#   'leader',
#   'accenture',
#   'verizon',
#   'lincoln',
#   'financial',
#   'group',
#   'servicenow',
#   'learn'],
#  ['week',
#   'julie_sweet',
#   'jimmy',
#   'etheredge',
#   'announce',
#   'action',
#   'we',
#   'take',
#   'fight',
#   'racism',
#   'come_together',
#   'push',
#   'progress',
#   'equal',
#   'future',
#   'testament',
#   'our',
#   'culture',
#   'core',
#   'value',
#   'we',
#   'take',
#   'action',
#   'we',
#   'lead',
#   'we',
#   'drive',
#   'change'],
#  ['note',
#   'jimmy',
#   'etheredge',
#   'I',
#   'send',
#   'today',
#   'people',
#   'reaffirm',
#   'our',
#   'unwavering',
#   'commitment',
#   'equality',
#   'justice',
#   'zero',
#   'tolerance',
#   'racism',
#   'bigotry',
#   'hate',
#   'kind',
#   'we',
#   'provide',
#   'update',
#   'commitment',
#   'we',
#   'make',
#   'june',
#   'announce',
#   'new',
#   'goal',
#   'we',
#   'mandatory',
#   'training',
#   'identify',
#   'speak',
#   'racism',
#   'community',
#   'investment',
#   'help',
#   'drive',
#   'change'],
#  ['bring',
#   'new',
#   'challenge',
#   'we',
#   'collaborate',
#   'our',
#   'partner',
#   'community',
#   'respond',
#   'recover',
#   'rebuild'],
#  ['we',
#   'know',
#   'sustainability',
#   'heart',
#   'business',
#   'we',
#   'get',
#   'you',
#   'you',
#   'get',
#   'close',
#   'sustainability',
#   'goal',
#   'all',
#   'without',
#   'miss',
#   'beat'],
#  ['people', 'depend', 'technology', 'ever', 'due', 'see'],
#  ['economic',
#   'progress',
#   'sustainability',
#   'go',
#   'hand',
#   'hand',
#   'our',
#   'europe',
#   'ceo',
#   'jeanmarc',
#   'ollagnier',
#   'share',
#   'thought',
#   'green',
#   'postpandemic',
#   'recovery'],
#  ['many',
#   'enterprise',
#   'effort',
#   'adopt',
#   'slow',
#   'stall',
#   'here',
#   'take',
#   'cloud',
#   'journey',
#   'next',
#   'level'],
#  ['wakeup',
#   'call',
#   'well',
#   'system',
#   'agility',
#   'adaptability',
#   'that',
#   's',
#   'come'],
#  ['help',
#   'organization',
#   'become',
#   'consistently',
#   'datadriven',
#   'start',
#   '7',
#   'step'],
#  ['reevaluate',
#   'recovery',
#   'strategy',
#   'pandemic',
#   'progress',
#   'plan',
#   'ahead',
#   'everchange',
#   'landscape'],
#  ['build',
#   'ventilator',
#   'analyze',
#   'travel',
#   'pattern',
#   'our',
#   'client',
#   'front',
#   'global',
#   'response',
#   'read',
#   'our',
#   'work',
#   'counter',
#   'pandemic',
#   'together'],
#  ['we',
#   'industry',
#   'expertise',
#   'know',
#   'make',
#   'business',
#   'tick',
#   'our',
#   'expert',
#   'take',
#   'you',
#   'deep',
#   'cloud',
#   'you',
#   'miss',
#   'beat'],
#  ['we',
#   'create',
#   'roadmap',
#   'help',
#   'company',
#   'capture',
#   'value',
#   'collaboration',
#   'uncertain',
#   'time',
#   'find'],
#  ['customer_experience',
#   'radically',
#   'change',
#   'and',
#   'expectation',
#   'here',
#   'company',
#   'evolve'],
#  ['despite',
#   'potential',
#   'also',
#   'create',
#   'new',
#   'challenge',
#   'organization',
#   'we_ve',
#   'find',
#   '5_key',
#   'focus',
#   'area',
#   'manage',
#   'cloud',
#   'service',
#   'effectively'],
#  ['☁',
#   '️',
#   '90',
#   'world',
#   'business',
#   'adopt',
#   'form',
#   'but',
#   '65',
#   'be_not',
#   'see',
#   'expect',
#   'result',
#   'here'],
#  ['nearly',
#   'twothird',
#   'enterprise',
#   'achieve',
#   'expect',
#   'benefit',
#   'migration',
#   'journey',
#   'barrier',
#   'face',
#   'find'],
#  ['business',
#   'organization',
#   'tackle',
#   'new',
#   'complex',
#   'problem',
#   'help',
#   'tool',
#   'read',
#   'find'],
#  ['honor',
#   'collaborate_fast',
#   'company',
#   'year',
#   'good_workplace',
#   'innovator',
#   'congrat',
#   'extraordinary',
#   'organization',
#   'create',
#   'culture',
#   'people',
#   'level',
#   'innovate',
#   'tech',
#   'financial',
#   'service',
#   'nonprofit',
#   'see',
#   'top',
#   '100'],
#  ['business',
#   'say',
#   'be_not',
#   'deliver',
#   'like',
#   'expect',
#   'our',
#   'new_report',
#   'show'],
#  ['accenture',
#   'brand',
#   'continue',
#   'increase',
#   'value',
#   '15',
#   'since',
#   'last',
#   'year',
#   'now',
#   'our',
#   '9th',
#   'consecutive_year',
#   'forbes',
#   'valuable',
#   'brand',
#   'list',
#   'huge',
#   'thank',
#   'our',
#   'client',
#   'every',
#   'one',
#   'our',
#   '500000',
#   'accenture',
#   'brand',
#   'ambassador'],
#  ['you',
#   'want',
#   'go',
#   'fast',
#   'go',
#   'alone',
#   'you',
#   'want',
#   'go',
#   'far',
#   'go',
#   'together',
#   'crossfunction',
#   'collaboration',
#   'matter'],
#  ['customer',
#   'employee',
#   'expect',
#   'organization',
#   'respond',
#   'global',
#   'challenge',
#   'meaningful',
#   'way',
#   'look',
#   'redefine',
#   'growth'],
#  ['hybrid',
#   'deployment',
#   'combine',
#   'good',
#   'public',
#   'private',
#   '3',
#   'key',
#   'factor',
#   'consider',
#   'you',
#   'implement'],
#  ['boost',
#   'competitiveness',
#   'path',
#   'postpandemic',
#   'recovery',
#   'our',
#   'europe',
#   'ceo',
#   'jean',
#   'marc',
#   'ollagnier',
#   'share',
#   'insight'],
#  ...]

# %%
from gensim.models import Word2Vec

# Define los parámetros de tu modelo personalizado
vector_size = 100
window_size = 5

# Construye el vocabulario de tu modelo utilizando las palabras del corpus tokenizado
model = Word2Vec(corpus_tok, vector_size=vector_size, window=window_size, min_count=1)

# Entrena el modelo Word2Vec con el corpus tokenizado
model.train(corpus_tok, total_examples=len(corpus_tok), epochs=500)

name_model= "biasAccenture_word2vec.model"
# Guarda el modelo entrenado para su uso posterior
model.save(name_model)

# %%
similares = model.wv.most_similar('nazism',topn=100)
similares
# Out:
# [('forget', 0.8754158616065979),
#  ('survivor', 0.7528197765350342),
#  ('victim', 0.7402528524398804),
#  ('holocaust', 0.7116933465003967),
#  ('persecute', 0.6705005168914795),
#  ('never', 0.6385380029678345),
#  ('history', 0.5943259000778198),
#  ('see_potential', 0.5347061157226562),
#  ('chandler', 0.5327220559120178),
#  ('playoff', 0.5323202013969421),
#  ('eastmankerry', 0.5318524241447449),
#  ('finale', 0.5307621955871582),
#  ('member', 0.530431866645813),
#  ('nazi', 0.5286093950271606),
#  ('endeavormichael', 0.5285435318946838),
#  ('experience_build', 0.5250692963600159),
#  ('elevate_evolve', 0.5182576179504395),
#  ('music', 0.5166335105895996),
#  ('ohare', 0.5150420665740967),
#  ('persecution', 0.512370765209198),
#  ('apple', 0.507515549659729),
#  ('expression', 0.5062142014503479),
#  ('ideal', 0.5043761730194092),
#  ('donna', 0.5009059309959412),
#  ('add_value', 0.5002369284629822),
#  ('pat', 0.49695876240730286),
#  ('embrace_change', 0.49621912837028503),
#  ('warner', 0.49583640694618225),
#  ('pacific', 0.4945909082889557),
#  ('discover_opportunity', 0.491675466299057),
#  ('wador', 0.4905497133731842),
#  ('estee', 0.4882074296474457),
#  ('raymond', 0.4874369502067566),
#  ('justice', 0.48738959431648254),
#  ('scalable', 0.48712876439094543),
#  ('pit', 0.4845805764198303),
#  ('😴', 0.483758807182312),
#  ('omnichannel', 0.4815765619277954),
#  ('🌲', 0.4791659712791443),
#  ('fall', 0.4768563210964203),
#  ('traveler', 0.4753763675689697),
#  ('happiness', 0.47106143832206726),
#  ('🌴', 0.47057682275772095),
#  ('deputy', 0.47017574310302734),
#  ('staff', 0.4690599739551544),
#  ('tedx', 0.46749475598335266),
#  ('77', 0.46677181124687195),
#  ('james•', 0.4661005139350891),
#  ('195', 0.46457338333129883),
#  ('impairment', 0.4640309810638428),
#  ('goodbye', 0.4633576273918152),
#  ('crew', 0.46283453702926636),
#  ('testa', 0.45885157585144043),
#  ('planting', 0.4579109847545624),
#  ('cognitive', 0.45731091499328613),
#  ('tolerance', 0.45437949895858765),
#  ('committed', 0.45343339443206787),
#  ('motivational', 0.45326873660087585),
#  ('tree', 0.45060813426971436),
#  ('alternative', 0.45041361451148987),
#  ('remembrance', 0.4498654901981354),
#  ('jeanmarc', 0.44831541180610657),
#  ('walk', 0.4480670690536499),
#  ('🍸', 0.4459599554538727),
#  ('coach', 0.44568929076194763),
#  ('chro', 0.44439682364463806),
#  ('150', 0.44433170557022095),
#  ('wastecurious', 0.44392630457878113),
#  ('homeownership', 0.4431237280368805),
#  ('stuckey', 0.4427158534526825),
#  ('clothe', 0.4425928294658661),
#  ('pambianchi', 0.4390178620815277),
#  ('livet', 0.4384888708591461),
#  ('prohibit', 0.43649786710739136),
#  ('lauderellyn', 0.4361370801925659),
#  ('ballot', 0.4351758658885956),
#  ('evan', 0.43491363525390625),
#  ('airline', 0.4319264888763428),
#  ('east', 0.43126213550567627),
#  ('samantha', 0.4294804632663727),
#  ('smiths', 0.42904046177864075),
#  ('wang', 0.4277667999267578),
#  ('som', 0.42751067876815796),
#  ('sheher', 0.42743316292762756),
#  ('🍹', 0.42644673585891724),
#  ('accept', 0.42612144351005554),
#  ('société', 0.42609840631484985),
#  ('💼', 0.4247964918613434),
#  ('motor', 0.4231816828250885),
#  ('cancer', 0.4227293133735657),
#  ('president', 0.42148980498313904),
#  ('jbg', 0.42130881547927856),
#  ('konsult', 0.42007437348365784),
#  ('local', 0.4188007116317749),
#  ('contact', 0.41858839988708496),
#  ('eliminate', 0.41748785972595215),
#  ('cmhc', 0.41548800468444824),
#  ('roman', 0.41504982113838196),
#  ('mph', 0.4150019586086273),
#  ('levi', 0.41499242186546326)]

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# cargar modelo entrenado
model = Word2Vec.load(name_model)

# obtener vectores de palabras entrenados por Word2Vec
word_vectors = model.wv.vectors

# aplicar PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(word_vectors)

# graficar los componentes principales
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.show()

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# cargar modelo entrenado
model = Word2Vec.load(name_model)

# obtener vectores de palabras entrenados por Word2Vec
word_vectors = model.wv.vectors

# aplicar PCA
pca = PCA(n_components=100)
principal_components = pca.fit_transform(word_vectors)

# aplicar k-means
kmeans = KMeans(n_clusters=50, random_state=0)
kmeans.fit(principal_components)

# graficar los resultados de k-means
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', s=100, linewidths=3, color='r')
plt.show()

# %%
# obtener las etiquetas de los clusters para cada punto en el espacio 2D producido por PCA
labels = kmeans.predict(principal_components)

# crear un diccionario para almacenar las palabras por cluster
clusters = {}

# agregar cada palabra al cluster correspondiente
for i, word in enumerate(model.wv.index_to_key):
    cluster = labels[i]
    if cluster not in clusters:
        clusters[cluster] = []
    clusters[cluster].append(word)

# imprimir palabras por cluster
for cluster, words in clusters.items():
    print(f"Cluster {cluster}: {words}")
# Out:
# Cluster 17: ['our', 'we', 'business', 'company', 'people', 'you', 'help', 'change', 'value', 'work', 'make', 'create', 'organization', 'world', 'and', 'way']
# Cluster 22: ['new', 'future', 'share', 'like', 'together', 'hear', '2020', 'right', 'climate_change', 'a', 'green', 'vision', 'ecosystem', 'economy', 'believe', 'excited', 'uncover', '🎉', 'successful', 'food', 'rapidly', 'fight', 'equal', 'idea', 'shake_share', 'chance', 'push', 'task', 'money', 'young', 'knowledge', 'number', 'dubai', 'education', 'saving', 'collaborate', 'tourism', 'code', 'showcase', 'girl', 'director', 'bright', 'expo', 'official', 'promotion', 'build_sustainable', 'techdriven', 'premier', 'spread', 'testament', 'difference', 'midyear', 'clean']
# Cluster 36: ['see', 'drive', 'here', 'consumer', 'deliver', 'sustainable', 'lead', 'accelerate', 'build', 'bring', 'employee', 'thrive', 'grow', 'provide', 'truly', 'understand', 'planet', 'benefit', 'shape', 'face', 'positive', 'relationship', 'adapt', 'unlock', 'customer_experience', 'balance', 'not', 'capture', 'huge', 'behavior', 'sustain']
# Cluster 6: ['find', 'leader', 'need', 'new_report', 'look', 'cloud', 'tech', 'sustainability', 'watch', 'full', 'insight', 'late', 'require', '✅', 'measure', 'return', 'cyber', 'expert', 'issue', 'annual_report', 'tool', 'want_work', 'outcome', 'fact', 'session', 'create_inclusive', 'cybersecurity', 'ceos_say', 'cyber_champion', 'be_not', 'edge', 'deep', 'shareholder', 'align', 'rebuild', 'secure', 'compute', 'blog', 'glasgow', 'seat', 'order', 'table', 'threatcentric']
# Cluster 33: ['technology', 'learn', 'growth', 'scale', 'strategy', 'ai', 'design', 'transform', 'potential', 'capability', 'core', 'intelligence', 'process', 'embed', 'system', 'intelligent', 'playbook', 'automation_advantage', 'leapfrog_peer', 'complex', 'efficiency', 'lifecentric', 'imperative', 'define', 'flexible', 'multidisciplinary']
# Cluster 15: ['one', 'become', 'every', 'move', 'must', 'turn', 'cost', 'could', 'project', 'in', 'miss', '🌎', 'allow', 'business_model', 'be', 'home', 'nearly', 'reinvent', 'continuum', 'target', 'de', 'reforest_land', 'native_specie', 'rebuild_biodiversity', 'make_agriculture', 'accelerate_transition', '2050', 'revolutionize', 'enhance', 'look_beyond', 'advantage', 'logementschl', 'et', 'felix', 'hit', 'digitally', 'efficient', 'poise', 'train', 'close', 'futureproof', 'productive', '30000', 'datapowered']
# Cluster 18: ['experience', 'start', 'next', 'matter', 'say', 'role', 'responsible', 'stakeholder', 'environment', 'evolve', 'play', 'we_ve', 'unique', 'listen', 'society', 'belong', 'model', 'resilient', 'board', 'promise', 'register', 'impact_stakeholder', 'protect', 'respond', 'themselves', 'profit', 'cmos', 'closely', 'situation', 'winwin']
# Cluster 34: ['explore']
# Cluster 48: ['team', 'human', 'speed', 'job', 'limit', 'day', 'everyone', 'city', 'dream', 'happen', 'without', 'work_together', '🤗', 'fan', 's', 'human_ingenuity', 'make_difference', 'communication', '💻', 'engage', 'microsoft', 'harness', 'housing', '\U0001fae7', 'climeworks', 'gap', 'omniconnecte_experience', 'salesforce', 'international', 'natural', 'integrate', 'climework', 'canada', 'mortgage', 'more', 'user', 'other', 'congrat', 'foster', 'artificial', 'mehmet', 'love', 'recently', 'archive', 'arolsen', 'academy', 'everywhere', 'sap', 'creativity', 'giant', '👏', 'with', 'digitize', 'marine', 'complete', 'able', 'produce', 'retail', '👋', 'edwin', 'shortage', 'vr', 'dheeraj', '🚛', 'house', '🚀', 'south', 'description', 'fuel', 'channel', '🦾', 'bridge', 'preserve', 'club', 'dimension', 'hyperscaler', 'principle', 'borrero', 'viewer', 'relevancy', '🐚', '🐙', 'orchestrate', '🐠', 'cover', 'engine', 'meritocratic', 'water', 'skys', 'difficult', 'codeorg', 'maker', 'racismaccenture', 'complianceasaservice', 'monte', 'del', 'rein', 'elearne', 'hotel', 'governmentcitizen', 'aidriven', 'aisports', 'bloom', 'permanently', 'carbon_removal', 'refugee', 'women', 'ukraine', 'closedloop', 'spend', 'longterm', 'granter', 'kickstart', 'revolution', '370000', 'therapy', 'mars', 'widen', 'being', 'resiliency', 'farmer', 'smarter', 'globo', 'release', 'wei', 'prison', 'surplus', 'divert', 'couple', 'clothing', 'pit', 'crew']
# Cluster 47: ['focus']
# Cluster 42: ['meet']
# Cluster 11: ['episode']
# Cluster 26: ['join_we', 'support', 'equality', 'commit', 'program', 'mean', 'stand', 'include', '2025', 'effort', 'emission', 'racism', 'significant', 'toward', 'naturebase_carbon', 'small', 'removal_project', 'speak', 'kind', 'colleague', 'lgbti', 'discrimination', 'identify', 'international_day', 'disability_inclusion', 'trans', 'member', 'authenticity', 'chair', '90', 'demonstrate', 'net', 'mandatory', 'corporate', 'retain', 'zero', 'training', 'initiative', '🌈', 'hate', 'still', 'racial', 'unwavering', 'transphobia', 'american', 'alongside', 'actual', 'strive', 'disabilityin', 'quest', 'stakeholdercentricity', '120000', 'black', 'african', 'inequality', 'reduction', 'congratulate', 'asian', '3bl', 'elimination', 'antitransgender', 'violence', 'bigotry', 'legislation', 'discriminatory', 'oppose', 'openness', 'vote', 'respect', 'tolerance', 'outside', 'lowcarbon', 'intolerance', 'accept', 'refuse', 'americanblack', '500', 'justice', 'ethnic', 'comment', 'biphobia', 'pacific', 'friend', 'solidarity', 'anotherand', 'further']
# Cluster 12: ['challenge', 'goal', 'achieve', 'big', 'priority', 'trust', 'set', 'many', 'united_nations', 'global_compact', 'five', 'influence', 'element', 'study', 'hold', 'rise', 'development', 'past', 'hero', 'achiever', 'barrier', 'especially', 'struggle', 'accountable', 'iconic', 'agile', 'apart', 'sharply', 'humanity']
# Cluster 43: ['use', 'client', 'join', 'discover', '💜', 'sustainable_future', 'check', 'also', '✨', 'industry_x', 'progress', 'personal', 'helping', 'partnership', 'innovative', 'space', 'field', '🌍', 'ever_wonder', 'spot', 'forge', 'every_direction', '360_°', 'level_playing', 'which', 'citizen', 'athlete', 'song', 'combination', 'dog', 'futuristic', 'cool', 'bt', 'cute', 'novel']
# Cluster 1: ['brand', 'connect', 'service', 'good', 'but', 'reach', 'develop', 'virtual', 'feel', 'skill', 'always', 'redefine', 'reveal', 'voice', 'thrilled', 'medium', 'shop', 'evolution', 'online', 'commerce', 'internal', 'interact', 'position', 'standard', 'speech', 'overcome', 'light', 'youth', 'socialize', 'blur', 'corner', 'skille', 'estimate', 'experiment', 'repetition', 'place_work', 'continually', 'self', '👗', 'augment', 'integrity', 'omniconnecte', 'schoolage', 'junior', 'usa', 'superb', 'exploit', 'skin', 'plenty', '4th', 'collaborative', '721000', 'external', 'josephtaiano', 'consume', 'prototyping', 'dollar']
# Cluster 40: ['key']
# Cluster 4: ['know', 'fast', 'come', 'go', 'want', 'journey', 'workforce', 'keep', 'you_know', 'long', 'dr_isi', 'heart', 'can_not', 'let', 'win', 'sense', 'hire', 'fabric', 'realize', 'book', 'already', 'really', 'place', 'device', 'mindset', 'possibility', '💡', 'work_like', 'extend', 'enough', 'alone', 'ai_maturity', 'remember', 'cut', 'wait', 'store', 'security', 'testimony', 'vital', 'exist', 'silo', 'fix', 'enjoy', 'would', 'input', 'peek', 'holistic', '😎', 'leap', 'massive', '🐶', 'simple', 'night', 'favorite', 'breach', 'tip', 'sign', 'creation', '🤩', 'backstage', 'legacy', 'confident', 'getting', 'hope', 'scaler', 'whole', 'fun', 'sneak', 'wherever', '🛍', 'exposure', 'companytocompany', 'tremendous', 'interest', 'height', 'doesnt', 'uplift', 'davo', 'reinventor', 'when', 'universe', 'alive', 'procrastinate', 'peril', 'hide', 'busy', 'blocker', 'category', 'fasttracke', 'fasttrack', 'route', 'yearbecause', 'll', 'whatever', 'mainly', 'map', 'stem']
# Cluster 30: ['story', 'career', 'her', 'real', 'everyday', 'mind', 'roof']
# Cluster 46: ['across']
# Cluster 24: ['great', 'datum', 'show', 'improve', 'result', 'combine', 'peer', 'high', 'essential', 'likely', 'apply', 'enable', 'boost', '4', 'continuum_opportunity', 'swipe', '7', 'revenue_growth', 'fully', 'maturity', 'resilience', 'ability', 'path', 'profitability', 'analytic', 'his_story', 'visibility', 'video', 'clear', 'migration', 'short', 'operational', 'purchasing', 'tap', 'entire', 'seize', 'application', 'finance', 'safety', 'infrastructure', 'master', 'unexpected', 'strength', 'fulfil', 'disrupt', 'link', 'exponential', 'engineer', 'reporting', 'state', 'multipli', 'effect', 'predictive', 'direction', 'delivery', 'box', '22', 'lever', 'curious', 'puzzle', '👠', 'moneta', 'vertical', 'technologyenabled']
# Cluster 27: ['recognize', 'honor', 'top', 'list', 'congratulation', 'woman', 'inclusion', 'index', '2021', 'diversity', 'worldwide', 'responsibility', 'consecutive_year', 'powerful_woman', 'rank', 'award', 'pride', 'lgbt', 'honored', 'sweet_recognize', 'fortune', 'among', 'champion', 'us', 'forbes', 'involve', 'recognition', 'outstanding', 'ethisphere', 'valuable', 'refinitiv', 'julie', 'cdp', '7th', 'highcaliber', 'lseg']
# Cluster 45: ['commitment', 'celebrate', 'around', 'thank_you', 'proud', 'inspire', 'thank', 'purpose', 'every_day', 'culture_equality', 'incredible', 'advance', 'around_world', 'empower', 'ally', 'chro_ellyn', 'inclusive', 'contribution', 'amazing', 'diverse', 'manage_director', 'inclusion_diversity', 'z', 'globe', 'uk', 'lgbtiq', 'month', 'child', 'volunteer', 'ellyn', 'sound', 'courage', 'achievement', 'remarkable', 'ana', 'representative']
# Cluster 41: ['solution']
# Cluster 19: ['explain', 'give', 'social', 'product', 'even', 'solve', 'rethink', 'million', 'health', 'physical', 'possible', 'content', 'tell', 'mental', '♀_️', 'something', '1_billion', 'accessible', 'problem', 'whether', 'ambition', 'smart', 'view', 'network', 'foundation', 'shopping', 'every_person', 'available', 'feel_like', 'immersive', 'build_inclusive', 'art', 'deepfake', 'lasting', 'radically', 'lens', 'privacy', 'invisible', 'responsibly', 'wellness', 'actively', 'data', 'datacentric', 'collection', 'emotional', 'sure', 'professional', 'offering', 'choice', 'patient', 'price', 'away', 'sell', '🍓', 'case', 'urgent', 'tony', 'significance', 'tick', 'teresa', 'authentic', 'purchase', 'harmony', 'ethiopa', 'merge', 'necessity', 'etisalat', '100000', '360degree', 'scaling', 'june', 'recruitment', 'regular', '💭', 'workin', 'pays', 'write', 'serendipitous', 'largescale', 'simulation', 'flourish', 'distribute', 'acquisitive', '120k', 'theatre', 'london', 'systematic', 'trustworthy', 'locationflexible', 'easier', 'intense', 'instability', 'paradoxical']
# Cluster 16: ['operation', '2022', 'important', '5', 'shift', 'first', 'ever', 'critical', 'answer', 'importance', 'question', 'late_report', 'topic', 'driver', 'awareness', 'mission', 'futureready', 'optimize', 'reevaluate', 'behind', '5_key', 'diagnostic', 'fall', '2023', 'area', 'ep', 'fundamental', 'pack', 'keeping', 'panelist']
# Cluster 44: ['think']
# Cluster 20: ['ceo_julie', 'ceo', 'sweet', 'discuss', 'davos', 'automation', 'implement', 'three', 'digital_transformation', 'talk', 'pride_mean', 'beyond', 'building', 'covid', 'panel', 'open', 'next_generation', 'tackle', 'ask', 'vehicle', 'seamless', 'address', 'access', 'marketing', 'suite', 'authentically', 'united', 'openly', 'optionborg', 'lean', 'wie', 'landit', 'drastically', 'depa', 'joe', 'tie', 'fitness', 'visibly', 'gamification', 'amid', 'parent', 'york', 'trending', 'roundtable', 'reveal_5', 'borderstech', 'qualcomm', 'avenue', 'permanente', 'bernard', 'tyson', 'kaiser', 'gupta', 'sulabh', 'agarwal', 'hillol', 'roy', 'jacky', 'fox', 'forkastnews', 'angie', 'lau', 'chano', 'coordinate', 'fernandez', 'youmna', 'naufal', 'zwift', 'cmo', 'steve', 'beckett', 'communityenriched', 'months', 'edition', 'industrialist', 'elena', 'moruzzi', 'pedro', 'accenture•', 'consult', 'sandeep', 'dadlani', 'digitalfirst', 'tech_adoption', 'ritual', 'unmet', 'purposedriven', 'match']
# Cluster 49: ['conversation', '👨', '👩', 'last', '30', '🏻', '🏼', 'raise', 'person_disability', 'office', '🏽', '🦰', 'host', 'speaker', '🏾', '✍', 'burke', 'molly', 'beck', 'hub', '🧔', '🦱', 'nov', 'author', 'screen', 'dasgupta', 'kaustuv', 'sai', 'illuminate', 'purple', 'blind', 'fade', 'coach', 'happiness']
# Cluster 35: ['supply_chain', 'reduce', 'management', 'risk', 'waste', 'invest', 'prepare', '10', 'strategic', 'lead_way', 'breakthrough', 'leap_ahead', 'four', 'point', '20', 'capital', 'maximize', '65', 'postpandemic', 'effectively', 'adopt', 'despite', 'replatform', 'lack', 'race', 'apparel', 'revenue', 'since', 'metric', 'yet', 'or', 'newfound', 'integration', 'techenabled', 'degree', 'auto', 'hunger', 'slow', 'customerobsesse', 'fair', 'datadriven', 'restrict', 'ventilator', 'trillion', 'proactive', 'prevent', 'strategically', '📈', 'pursue', 'overall', 'enzyme', 'productcentric', 'plastic', 'norway', 'lower', 'source', 'scientific', 'reset', 'upskilling', 'geography', 'usually', '80', 'consequence', '35', '3x', 'conference', 'broaden', 'stall', 'switch', 'clearly', 'survival', 'compressed', 'procurement', 'mining', 'metal', 'reframe', 'migrate', 'eligible', 'inflection', 'voter', 'treat', 'inaugural', 'glassdoor', 'mit', 'sloan', 'modernization', 'nine', 'outpace', 'rate', 'percentage', 'contingency', 'underprepare', 'halfway', 'footprint', 'compare', '2x', 'extensively', 'govern', 'rigorous', 'portfolio', 'pair', 'piecemeal', 'hence', 'timeline', 'dow', 'experimentation', 'production', 'status', 'solutioning', 'guesswork', 'ramp', 'twothird', '8356', 'exempt', 'circularity', 'altogetherit', 'fouryear', 'posttraumatic', 'china', 'astounding', 'multibilliondollar', 'packaging', 'beset', 'ingenuity', 'ultimate', '€', 'hefty', 'priceless', 'reinvest', 'slowing', '💁', 'dominate', 'peoplepowered', 'companythe', 'material', 'restructure', 'careful', 'unintended', 'occur']
# Cluster 29: ['add_value', 'embrace_change', 'discover_opportunity', '360˚_value', 'elevate_evolve', 'experience_build', 'see_potential', 'chief', 'discussion', 'wire', 'competitiveness', 'innovation_read', 'forum', 'feature', 'beyond_migration', 'atmosphere', 'text', 'world_economic', 'executive', 'supply_unbounde', 'share_unleash', 'key_tenet', 'reveal_4', 'jill_kramer', '🧑', 'senior', '20_year', 'remove_13', 'million_metric', 'ton_carbon', 'chro', '15', 'electric', 'physically', 'dhypothèques', 'canadienne', 'société', 'dr', 'sanjeev', 'vohra', 'cmhc', '🏢', 'foresight', 'president', 'morris', 'pambianchi', 'pat', 'wador', 'lisa', 'christy', 'artist', 'md', 'christine', 'ok', 'meeting', 'guan', 'bettingerbuckingham', 'donna', 'winner', 'appointment', 'vice', 'village', 'interview', 'jack', 'azagury', 'stigma', 'nick', 'national', 'mba', 'dupervalbrownlee', 'tamarah', 'computer', 'crossindustry', 'servicenow', 'shaper', 'ctio', 'local', 'tedx', 'motivational', 'wang', 'jefferson', 'thompson', '🍹', 'pioneer', 'stephanie', 'deputy', 'accentures', 'angel',
'anticipate', 'sustainably', 'forefront', 'fulfillment', 'marketplace', 'simplicity', 'endtoendless', 'expertly', 'participant', 'multitasker', 'multiply', 'importantly', 'cxos', 'lay', '💼', 'type', 'computational', 'fluctuating', 'resourcing', 'skilled', 'deeply', 'disconnect', 'resolve', 'execution', 'pressure', 'oversight', 'onetime', 'wifi', 'icon', 'politic', 'little', '460000', 'retentionfrom', 'ban', '16000', 'pdf', 'jargon', 'professionalization', 'peaceful', 'reemphasize', 'forrester', 'prioritize', 'presidential', 'unpatched', 'election', 'untested', 'genuine', 'interaction', 'prefer', 'interpersonal', 'trait', '57', 'realtime', 'trend_drive', 'hour', 'workday', '😍', 'optional', 'intuition', 'realignment', 'personalized', 'establish', 'suffer', 'misaligned', 'while', 'desire', 'these', 'jump', 'acceleration', 'intimacy', 'oversee', 'hell', 'december', 'industryleade', 'chinabased', 'healthy', '❌', 'snow', 'jones', 'boot', '🎿', 'fluency', 'radisson', 'revamp', 'objective', 'csuite', 'highre', 'consistently', '71', 'private', 'deployment', 'hospital', 'compress', 'airlines', '4️⃣', 'throughout', 'organizationthis', 'electricity', 'communicate', '😉', 'sometimes', 'reminderthe', 'co₂', 'childcare', 'astha', 'bhardwaj', 'hospitality', 'miguel', 'flecha', 'door', '12day', '️collect', '💚', 'accurately', 'suriel', 'differentiated', 'strategy1️⃣', 'simple2️⃣', 'seamless3️⃣', 'scaled4️⃣', 'repetitive', '🥽', 'metaverse🦾', 'southeast', 'sustainabilityminded', 'indonesia', 'equipment', 'urgently', 'tedious', 'untapped', 'omnichannel', 'reimage', 'streaming', '🛠', 'telco', 'bolster', 'energized', '89', 'industrialization', 'declutter', 'mundane', 'emobility', 'oems', 'ownership', 'optimal', 'else', 'phenomenon', 'exec', 'clarity', 'component', 'tetra', 'paks', 'avatar', 'investmenthow', 'supervisor', '⚖', 'affordability', 'sustainabilityinnovation', 'kpis', 'prosperity', 'equitably', 'selfefficacy', '🛒', 'hidden', 'regeneration', 'leapfrogger', 'realness', 'sizzle', 'miner', 'charge', '20yearold', 'centricity', 'enoughcompanie', 'detection', 'disease', '43', 'computing', 'ignite', 'abandon', 'needsthe', 'elevate', 'pool', '21', '72', 'recruiting', 'reignite', 'chase', 'businesse', 'hpc', 'biologyinspired', 'broadcasting', '💪', 'digitallysavvy', 'predominantly', 'selffunde', 'web3', 'oneofakind', 'boom', 'adviser', '74', 'fastfood', 'databased', '25000', 'style', 'onthejob', 'object', 'cheap', 'reputation', 'highperforming', 'techforward', '69', 'behave', 'exception', 'hering', 'car', 'comfort', 'satisfy', 'buying', 'mirco', 'laserfocused', 'sky', 'inconsistently', 'accommodation', 'profitable', 'circumstance', 'modernize', 'settle', 'confused', 'holistically', 'outgrow', 'preparation', 'constant', 'insufficient', 'turnover']
'frame', 'ticket', 'ambassador', 'robotic', 'synche', 'restore', 'player', 'enjoyable', 'siloed', 'guideline', 'hybrid', 'manufacturer', 'meal', 'before', 'outperformedtheir', 'conventional', 'counterpart', 'valuesdriven', 'seem', 'redistribute', 'reactive', 'regenerative', 'careology', 'cancer', '📙', 'tuning', 'simone', 'willingness', 'dialogue', 'underground', 'empty', '🌡', 'rule', 'thrivetoday', 'neurodiversity', 'viewing', 'extension', 'payment', 'multimodal', 'mobility', 'fintech', 'autism', 'acceptance', 'fantasy', '🦄', 'spending', 'observe', 'excitement', 'confusion', 'skepticism', 'inbox', 'unstoppable', 'another', 'sustainedlisten', 'belongcongratulation', 'version', 'industryspecific', 'survivor', 'publicprivate', 'myth', 'judgement', 'empathy', 'technologyenable', 'sole', '🏌', 'drama', 'unpredictable', 'predictable', '55', 'gdp', 'baking', 'balanced', 'ambitious', 'decisionmaker' ...
# Cluster 0: ['indepth']

# %%
import nltk
import re
import collections

limpio = []

for doc in clean_corpus:
    doc = doc.lower()
    palabras = re.findall(r'\b\w+\b', doc)
    limpio.extend(palabras)

frecuencia_palabras = collections.Counter(limpio).most_common()
num_palabras = len(limpio)
frecuencia_porcentaje = {palabra: (frecuencia/num_palabras)*100 for palabra, frecuencia in frecuencia_palabras}

for palabra, frecuencia in sorted(frecuencia_porcentaje.items(), key=lambda item: item[1], reverse=True):
    print(palabra, ": ", round(frecuencia, 2), "%")
# Out:
# our :  3.8 %
# we :  2.22 %
# business :  1.3 %
# company :  1.12 %
# people :  0.99 %
# new :  0.92 %
# you :  0.88 %
# help :  0.83 %
# see :  0.79 %
# change :  0.73 %
# value :  0.71 %
# work :  0.65 %
# make :  0.64 %
# find :  0.62 %
# technology :  0.61 %
# learn :  0.55 %
# create :  0.54 %
# organization :  0.54 %
# world :  0.46 %
# need :  0.46 %
# leader :  0.46 %
# and :  0.45 %
# future :  0.4 %
# share :  0.39 %
# one :  0.38 %
# experience :  0.37 %
# innovation :  0.37 %
# well :  0.36 %
# get :  0.34 %
# accenture :  0.34 %
# take :  0.34 %
# read :  0.34 %
# report :  0.32 %
# drive :  0.32 %
# way :  0.31 %
# here :  0.29 %
# impact :  0.29 %
# industry :  0.29 %
# live :  0.29 %
# year :  0.28 %
# community :  0.28 %
# today :  0.27 %
# growth :  0.27 %
# customer :  0.27 %
# digital :  0.26 %
# life :  0.26 %
# consumer :  0.25 %
# global :  0.25 %
# new_report :  0.25 %
# explore :  0.24 %
# time :  0.23 %
# look :  0.23 %
# team :  0.23 %
# sustainable :  0.21 %
# deliver :  0.21 %
# focus :  0.21 %
# cloud :  0.21 %
# meet :  0.2 %
# episode :  0.2 %
# tech :  0.2 %
# join_we :  0.2 %
# action :  0.19 %
# partner :  0.19 %
# sustainability :  0.19 %
# challenge :  0.19 %
# lead :  0.19 %
# accelerate :  0.19 %
# human :  0.19 %
# scale :  0.19 %
# become :  0.18 %
# like :  0.18 %
# goal :  0.18 %
# strategy :  0.18 %
# power :  0.18 %
# watch :  0.18 %
# use :  0.18 %
# brand :  0.17 %
# key :  0.17 %
# client :  0.17 %
# join :  0.17 %
# know :  0.17 %
# build :  0.17 %
# connect :  0.16 %
# ai :  0.16 %
# story :  0.16 %
# opportunity :  0.16 %
# across :  0.16 %
# career :  0.16 %
# service :  0.16 %
# start :  0.16 %
# design :  0.16 %
# great :  0.16 %
# _ :  0.16 %
# support :  0.16 %
# discover :  0.15 %
# recognize :  0.15 %
# leadership :  0.15 %
# commitment :  0.15 %
# next :  0.15 %
# equality :  0.15 %
# fast :  0.15 %
# come :  0.15 %
# full :  0.14 %
# around :  0.14 %
# celebrate :  0.14 %
# together :  0.14 %
# honor :  0.14 %
# matter :  0.14 %
# top :  0.14 %
# good :  0.14 %
# employee :  0.14 %
# insight :  0.14 %
# bring :  0.14 %
# thank_you :  0.14 %
# podcast :  0.14 %
# go :  0.14 %
# hear :  0.14 %
# trend :  0.13 %
# solution :  0.13 %
# transform :  0.13 %
# every :  0.13 %
# list :  0.13 %
# workplace :  0.13 %
# explain :  0.13 %
# inspire :  0.13 %
# proud :  0.13 %
# continue :  0.13 %
# late :  0.13 %
# operation :  0.13 %
# her :  0.12 %
# thrive :  0.12 %
# say :  0.12 %
# 2022 :  0.12 %
# congratulation :  0.12 %
# ceo_julie :  0.12 %
# think :  0.12 %
# responsible :  0.12 %
# grow :  0.12 %
# enterprise :  0.12 %
# role :  0.12 %
# achieve :  0.12 %
# sustainable_future :  0.12 %
# culture :  0.12 %
# ceo :  0.12 %
# 2020 :  0.12 %
# 5 :  0.11 %
# investment :  0.11 %
# want :  0.11 %
# important :  0.11 %
# care :  0.11 %
# stakeholder :  0.11 %
# increase :  0.11 %
# platform :  0.11 %
# talent :  0.11 %
# reimagine :  0.11 %
# thank :  0.11 %
# ahead :  0.1 %
# right :  0.1 %
# datum :  0.1 %
# but :  0.1 %
# commit :  0.1 %
# approach :  0.1 %
# step :  0.1 %
# speed :  0.1 %
# conversation :  0.1 %
# what_s :  0.1 %
# check :  0.1 %
# discuss :  0.1 %
# shift :  0.1 %
# purpose :  0.1 %
# big :  0.1 %
# require :  0.1 %
# embrace :  0.1 %
# provide :  0.1 %
# his :  0.1 %
# supply_chain :  0.1 %
# move :  0.1 %
# sweet :  0.1 %
# pandemic :  0.1 %
# reality :  0.09 %
# truly :  0.09 %
# woman :  0.09 %
# potential :  0.09 %
# also :  0.09 %
# show :  0.09 %
# ever :  0.09 %
# reach :  0.09 %
# first :  0.09 %
# journey :  0.09 %
# podcast_ :  0.09 %
# adoption :  0.09 %
# planet :  0.09 %
# follow :  0.09 %
# core :  0.09 %
# industry_x :  0.09 %
# environment :  0.09 %
# every_day :  0.09 %
# improve :  0.09 %
# evolve :  0.09 %
# understand :  0.09 %
# must :  0.09 %
# priority :  0.09 %
# capability :  0.09 %
# culture_equality :  0.09 %
# develop :  0.09 %
# program :  0.09 %
# virtual :  0.08 %
# strong :  0.08 %
# climate_change :  0.08 %
# set :  0.08 %
# disruption :  0.08 %
# trust :  0.08 %
# discover_opportunity :  0.08 %
# add_value :  0.08 %
# embrace_change :  0.08 %
# reduce :  0.08 %
# expect :  0.08 %
# social :  0.08 %
# collaboration :  0.08 %
# progress :  0.08 %
# mean :  0.08 %
# combine :  0.08 %
# intelligence :  0.08 %
# thing :  0.08 %
# give :  0.08 %
# call :  0.08 %
# shape :  0.08 %
# travel :  0.08 %
# research :  0.08 %
# benefit :  0.08 %
# result :  0.08 %
# market :  0.08 %
# job :  0.08 %
# incredible :  0.08 %
# success :  0.08 %
# critical :  0.08 %
# 360 :  0.08 %
# innovator :  0.08 %
# turn :  0.08 %
# limit :  0.07 %
# keep :  0.07 %
# day :  0.07 %
# process :  0.07 %
# part :  0.07 %
# include :  0.07 %
# high :  0.07 %
# performance :  0.07 %
# financial :  0.07 %
# everything :  0.07 %
# davos :  0.07 %
# last :  0.07 %
# peer :  0.07 %
# essential :  0.07 %
# listen :  0.07 %
# inclusion :  0.07 %
# many :  0.07 %
# a :  0.07 %
# advance :  0.07 %
# _value :  0.07 %
# stand :  0.07 %
# workforce :  0.07 %
# automation :  0.07 %
# transformation :  0.07 %
# even :  0.07 %
# feel :  0.07 %
# everyone :  0.07 %
# week :  0.07 %
# play :  0.07 %
# name :  0.07 %
# 3 :  0.07 %
# product :  0.07 %
# tune :  0.07 %
# science :  0.07 %
# embed :  0.07 %
# likely :  0.07 %
# answer :  0.07 %
# management :  0.07 %
# always :  0.07 %
# skill :  0.07 %
# break :  0.07 %
# index :  0.07 %
# green :  0.07 %
# elevate_evolve :  0.07 %
# experience_build :  0.07 %
# see_potential :  0.07 %
# 2025 :  0.07 %
# announce :  0.07 %
# ready :  0.06 %
# 4 :  0.06 %
# redefine :  0.06 %
# you_know :  0.06 %
# around_world :  0.06 %
# million :  0.06 %
# project :  0.06 %
# city :  0.06 %
# three :  0.06 %
# 1 :  0.06 %
# discussion :  0.06 %
# united_nations :  0.06 %
# could :  0.06 %
# enable :  0.06 %
# inside :  0.06 %
# we_ve :  0.06 %
# apply :  0.06 %
# waste :  0.06 %
# innovate :  0.06 %
# solve :  0.06 %
# personal :  0.06 %
# chief :  0.06 %
# unique :  0.06 %
# put :  0.06 %
# rethink :  0.06 %
# leverage :  0.06 %
# good_workplace :  0.06 %
# 2021 :  0.06 %
# guide :  0.06 %
# cost :  0.06 %
# effort :  0.06 %
# face :  0.06 %
# risk :  0.06 %
# implement :  0.06 %
# system :  0.06 %
# invest :  0.06 %
# measure :  0.06 %
# long :  0.06 %
# belong :  0.06 %
# dream :  0.06 %
# diversity :  0.06 %
# return :  0.06 %
# boost :  0.06 %
# empower :  0.06 %
# positive :  0.06 %
# vision :  0.06 %
# competitive :  0.06 %
# helping :  0.06 %
# relationship :  0.06 %
# reason :  0.06 %
# adapt :  0.06 %
# practice :  0.06 %
# in :  0.06 %
# ally :  0.06 %
# talk :  0.06 %
# society :  0.06 %
# relevance :  0.06 %
# fortune_magazine :  0.06 %
# health :  0.06 %
# real :  0.06 %
# prepare :  0.06 %
# emission :  0.06 %
# navigate :  0.06 %
# ecosystem :  0.06 %
# ensure :  0.06 %
# cyber :  0.06 %
# digital_transformation :  0.06 %
# dr_isi :  0.06 %
# continuum_opportunity :  0.06 %
# it :  0.05 %
# do_not :  0.05 %
# without :  0.05 %
# allow :  0.05 %
# heart :  0.05 %
# miss :  0.05 %
# happen :  0.05 %
# unlock :  0.05 %
# wire :  0.05 %
# let :  0.05 %
# moment :  0.05 %
# replay :  0.05 %
# feature :  0.05 %
# ellyn_shake :  0.05 %
# partnership :  0.05 %
# global_compact :  0.05 %
# issue :  0.05 %
# expert :  0.05 %
# can_not :  0.05 %
# win :  0.05 %
# force :  0.05 %
# 30 :  0.05 %
# disability :  0.05 %
# landscape :  0.05 %
# towards :  0.05 %
# inclusive :  0.05 %
# innovative :  0.05 %
# annual_report :  0.05 %
# pride_mean :  0.05 %
# pivot :  0.05 %
# 10 :  0.05 %
# intelligent :  0.05 %
# forum :  0.05 %
# business_model :  0.05 %
# chro_ellyn :  0.05 %
# innovation_read :  0.05 %
# competitiveness :  0.05 %
# work_connect :  0.05 %
# tool :  0.05 %
# save :  0.05 %
# physical :  0.05 %
# swipe :  0.05 %
# beyond :  0.05 %
# offer :  0.05 %
# decision :  0.05 %
# worker :  0.05 %
# different :  0.05 %
# accenture_foresight :  0.05 %
# content :  0.05 %
# resilient :  0.05 %
# app :  0.05 %
# space :  0.05 %
# level :  0.05 %
# interactive :  0.05 %
# fully :  0.05 %
# possible :  0.05 %
# worldwide :  0.05 %
# contribution :  0.05 %
# revenue_growth :  0.05 %
# model :  0.05 %
# work_together :  0.05 %
# building :  0.05 %
# thought :  0.05 %
# all :  0.05 %
# economy :  0.05 %
# remove :  0.05 %
# 7 :  0.05 %
# gain :  0.05 %
# believe :  0.05 %
# beyond_migration :  0.05 %
# continuum_competitor :  0.05 %
# gary :  0.05 %
# five :  0.05 %
# strategic :  0.05 %
# racism :  0.05 %
# emerge :  0.04 %
# event :  0.04 %
# reinvention :  0.04 %
# plan :  0.04 %
# sense :  0.04 %
# text :  0.04 %
# excited :  0.04 %
# much :  0.04 %
# reveal :  0.04 %
# toward :  0.04 %
# provider :  0.04 %
# board :  0.04 %
# everyday :  0.04 %
# six :  0.04 %
# fan :  0.04 %
# uncover :  0.04 %
# importance :  0.04 %
# agenda :  0.04 %
# panel :  0.04 %
# download :  0.04 %
# julie_sweet :  0.04 %
# extraordinary :  0.04 %
# executive :  0.04 %
# field :  0.04 %
# traditional :  0.04 %
# ceos :  0.04 %
# annual :  0.04 %
# environmental :  0.04 %
# incredible_people :  0.04 %
# the :  0.04 %
# metaverse :  0.04 %
# want_work :  0.04 %
# raise :  0.04 %
# economic :  0.04 %
# playbook :  0.04 %
# person_disability :  0.04 %
# climate :  0.04 %
# fact :  0.04 %
# stay :  0.04 %
# amazing :  0.04 %
# maturity :  0.04 %
# line :  0.04 %
# balance :  0.04 %
# customer_experience :  0.04 %
# carbon :  0.04 %
# dna :  0.04 %
# crisis :  0.04 %
# atmosphere :  0.04 %
# covid :  0.04 %
# expectation :  0.04 %
# outcome :  0.04 %
# hire :  0.04 %
# daily :  0.04 %
# that :  0.04 %
# significant :  0.04 %
# 100 :  0.04 %
# resilience :  0.04 %
# world_economic :  0.04 %
# small :  0.04 %
# question :  0.04 %
# fabric :  0.04 %
# preorder :  0.04 %
# responsibility :  0.04 %
# promise :  0.04 %
# discover_trend :  0.04 %
# naturebase_carbon :  0.04 %
# ever_wonder :  0.04 %
# tomorrow :  0.04 %
# already :  0.04 %
# trend_shape :  0.04 %
# lead_way :  0.04 %
# gender :  0.04 %
# open :  0.04 %
# manage_director :  0.04 %
# path :  0.04 %
# profitability :  0.04 %
# communication :  0.04 %
# nearly :  0.04 %
# spot :  0.04 %
# expand :  0.04 %
# excite :  0.04 %
# meaningful :  0.04 %
# inclusion_diversity :  0.04 %
# perspective :  0.04 %
# tell :  0.04 %
# breakthrough :  0.04 %
# factor :  0.04 %
# book :  0.04 %
# session :  0.04 %
# speak :  0.04 %
# office :  0.04 %
# element :  0.04 %
# create_inclusive :  0.04 %
# awareness :  0.04 %
# food :  0.04 %
# every_direction :  0.04 %
# powerful_woman :  0.04 %
# research_show :  0.04 %
# forge :  0.04 %
# analytic :  0.04 %
# healthcare :  0.04 %
# hr :  0.04 %
# 1_billion :  0.04 %
# accessible :  0.04 %
# something :  0.04 %
# consecutive_year :  0.04 %
# realize :  0.04 %
# great_place :  0.04 %
# product_service :  0.04 %
# i :  0.04 %
# mental :  0.04 %
# officer :  0.04 %
# back :  0.04 %
# diverse :  0.04 %
# voice :  0.04 %
# need_strengthen :  0.04 %
# be :  0.04 %
# detail :  0.04 %
# not :  0.04 %
# driver :  0.04 %
# home :  0.04 %
# era :  0.04 %
# successful :  0.04 %
# ability :  0.04 %
# make_difference :  0.04 %
# they :  0.04 %
# individual :  0.04 %
# mind :  0.04 %
# collaborate_fast :  0.04 %
# s :  0.04 %
# bold :  0.04 %
# topic :  0.04 %
# next_week :  0.04 %
# human_ingenuity :  0.04 %
# influence :  0.04 %
# register :  0.04 %
# automation_advantage :  0.04 %
# reveal_4 :  0.04 %
# key_tenet :  0.04 %
# share_unleash :  0.04 %
# supply_unbounde :  0.04 %
# sustainable_purpose :  0.04 %
# real_virtualitiesare :  0.04 %
# signal_business :  0.04 %
# change_radar :  0.04 %
# removal_project :  0.04 %
# create_green :  0.04 %
# late_report :  0.04 %
# leap_ahead :  0.04 %
# possibility :  0.03 %
# four :  0.03 %
# place :  0.03 %
# video :  0.03 %
# end :  0.03 %
# barcelona :  0.03 %
# energy :  0.03 %
# network :  0.03 %
# 360_ :  0.03 %
# free :  0.03 %
# protect :  0.03 %
# rank :  0.03 %
# mindset :  0.03 %
# be_not :  0.03 %
# colleague :  0.03 %
# family :  0.03 %
# game :  0.03 %
# paul_daugherty :  0.03 %
# jill_kramer :  0.03 %
# broadcast :  0.03 %
# study :  0.03 %
# next_generation :  0.03 %
# short :  0.03 %
# capture :  0.03 %
# mission :  0.03 %
# whether :  0.03 %
# rapidly :  0.03 %
# fight :  0.03 %
# smart :  0.03 %
# microsoft :  0.03 %
# billion :  0.03 %
# manufacture :  0.03 %
# problem :  0.03 %
# device :  0.03 %
# really :  0.03 %
# 50 :  0.03 %
# target :  0.03 %
# do :  0.03 %
# view :  0.03 %
# housing :  0.03 %
# harness :  0.03 %
# clear :  0.03 %
# consider :  0.03 %
# direct :  0.03 %
# cybersecurity :  0.03 %
# impact_stakeholder :  0.03 %
# pay :  0.03 %
# transition :  0.03 %
# act :  0.03 %
# kind :  0.03 %
# powerful :  0.03 %
# come_together :  0.03 %
# his_story :  0.03 %
# engage :  0.03 %
# reinvent :  0.03 %
# z :  0.03 %
# visibility :  0.03 %
# half :  0.03 %
# continuum :  0.03 %
# huge :  0.03 %
# ceos_say :  0.03 %
# cyber_champion :  0.03 %
# thriver :  0.03 %
# report_reveal :  0.03 %
# accelerate_tech :  0.03 %
# ambition :  0.03 %
# senior :  0.03 %
# leapfrog_peer :  0.03 %
# lgbti :  0.03 %
# migration :  0.03 %
# efficiency :  0.03 %
# exciting :  0.03 %
# special :  0.03 %
# next_decade :  0.03 %
# available :  0.03 %
# continuous :  0.03 %
# point :  0.03 %
# serve :  0.03 %
# store :  0.03 %
# at_work :  0.03 %
# thrilled :  0.03 %
# row :  0.03 %
# award :  0.03 %
# remember :  0.03 %
# reflect :  0.03 %
# discrimination :  0.03 %
# fall :  0.03 %
# align :  0.03 %
# 15 :  0.03 %
# europe :  0.03 %
# linkedin :  0.03 %
# icymi :  0.03 %
# exclusive :  0.03 %
# forward :  0.03 %
# medium :  0.03 %
# revolutionize :  0.03 %
# ask :  0.03 %
# capital :  0.03 %
# immersive :  0.03 %
# boundary :  0.03 %
# salesforce :  0.03 %
# reshape :  0.03 %
# gap :  0.03 %
# leave :  0.03 %
# wait :  0.03 %
# shareholder :  0.03 %
# tour :  0.03 %
# championship :  0.03 %
# idea :  0.03 %
# ai_maturity :  0.03 %
# re :  0.03 %
# deep :  0.03 %
# holiday :  0.03 %
# behavior :  0.03 %
# uk :  0.03 %
# creator :  0.03 %
# sweet_recognize :  0.03 %
# honored :  0.03 %
# omniconnecte_experience :  0.03 %
# level_playing :  0.03 %
# international_day :  0.03 %
# quality :  0.03 %
# host :  0.03 %
# build_inclusive :  0.03 %
# 12 :  0.03 %
# hold :  0.03 %
# survey :  0.03 %
# lgbt :  0.03 %
# 2050 :  0.03 %
# shopping :  0.03 %
# 20 :  0.03 %
# optimize :  0.03 %
# pride :  0.03 %
# foundation :  0.03 %
# climeworks :  0.03 %
# corporation :  0.03 %
# de :  0.03 %
# demand :  0.03 %
# expertise :  0.03 %
# security :  0.03 %
# enhance :  0.03 %
# rise :  0.03 %
# group :  0.03 %
# diagnostic :  0.03 %
# behind :  0.03 %
# differently :  0.03 %
# 5_key :  0.03 %
# drug :  0.03 %
# true :  0.03 %
# manage :  0.03 %
# feel_like :  0.03 %
# positive_impact :  0.03 %
# tap :  0.03 %
# maximize :  0.03 %
# entire :  0.03 %
# look_beyond :  0.03 %
# country :  0.03 %
# extend :  0.03 %
# resource :  0.03 %
# accessibility :  0.03 %
# enough :  0.03 %
# operational :  0.03 %
# every_person :  0.03 %
# aipowered :  0.03 %
# tackle :  0.03 %
# equal :  0.03 %
# globe :  0.03 %
# complex :  0.03 %
# welcome :  0.03 %
# edge :  0.03 %
# generate :  0.03 %
# architect :  0.03 %
# work_like :  0.03 %
# shake :  0.03 %
# identify :  0.03 %
# purchasing :  0.03 %
# alone :  0.03 %
# cut :  0.03 %
# accelerate_transition :  0.03 %
# futureready :  0.03 %
# reevaluate :  0.03 %
# chro :  0.03 %
# air_find :  0.03 %
# global_warming :  0.03 %
# reforest_land :  0.03 %
# native_specie :  0.03 %
# rebuild_biodiversity :  0.03 %
# make_agriculture :  0.03 %
# rebound :  0.03 %
# co2 :  0.03 %
# 20_year :  0.03 %
# remove_13 :  0.03 %
# million_metric :  0.03 %
# ton_carbon :  0.03 %
# pull :  0.03 %
# practical :  0.03 %
# update :  0.03 %
# agility :  0.03 %
# shake_share :  0.03 %
# report_explain :  0.03 %
# dig :  0.03 %
# omar_abbosh :  0.03 %
# transparency :  0.02 %
# radically :  0.02 %
# area :  0.02 %
# less :  0.02 %
# vehicle :  0.02 %
# designer :  0.02 %
# 2023 :  0.02 %
# international :  0.02 %
# champion :  0.02 %
# total :  0.02 %
# electric :  0.02 %
# more :  0.02 %
# finance :  0.02 %
# introduce :  0.02 %
# exist :  0.02 %
# volunteer :  0.02 %
# member :  0.02 %
# 2 :  0.02 %
# citizen :  0.02 %
# dr :  0.02 %
# application :  0.02 %
# via :  0.02 %
# unprecedented :  0.02 %
# 6 :  0.02 %
# which :  0.02 %
# instagram :  0.02 %
# can :  0.02 %
# sanjeev :  0.02 %
# vohra :  0.02 %
# advantage :  0.02 %
# art :  0.02 %
# month :  0.02 %
# felix :  0.02 %
# chair :  0.02 %
# forbes :  0.02 %
# postpandemic :  0.02 %
# disability_inclusion :  0.02 %
# speaker :  0.02 %
# us :  0.02 %
# trans :  0.02 %
# vital :  0.02 %
# lifecentric :  0.02 %
# old :  0.02 %
# customercentric :  0.02 %
# involve :  0.02 %
# among :  0.02 %
# canada :  0.02 %
# mortgage :  0.02 %
# cmhc :  0.02 %
# société :  0.02 %
# canadienne :  0.02 %
# dhypothèques :  0.02 %
# et :  0.02 %
# logementschl :  0.02 %
# seamless :  0.02 %
# lgbtiq :  0.02 %
# child :  0.02 %
# habit :  0.02 %
# represent :  0.02 %
# deepfake :  0.02 %
# software :  0.02 %
# takeaway :  0.02 %
# shop :  0.02 %
# development :  0.02 %
# online :  0.02 %
# year_list :  0.02 %
# lab :  0.02 %
# integrate :  0.02 %
# quickly :  0.02 %
# inspiration :  0.02 %
# cfos :  0.02 %
# address :  0.02 %
# freedom :  0.02 %
# 90 :  0.02 %
# enjoy :  0.02 %
# climework :  0.02 %
# 65 :  0.02 %
# fix :  0.02 %
# chat :  0.02 %
# evolution :  0.02 %
# twin :  0.02 %
# netzero :  0.02 %
# authenticity :  0.02 %
# respond :  0.02 %
# adaptability :  0.01 %
# sai :  0.01 %
# kaustuv :  0.01 %
# dasgupta :  0.01 %
# screen :  0.01 %
# robot :  0.01 %
# nov :  0.01 %
# author :  0.01 %
# within :  0.01 %
# cool :  0.01 %
# transphobia :  0.01 %
# achiever :  0.01 %
# begin :  0.01 %
# giant :  0.01 %
# fundamental :  0.01 %
# engineer :  0.01 %
# everchange :  0.01 %
# maintain :  0.01 %
# founder :  0.01 %
# affordable :  0.01 %
# blog :  0.01 %
# quantum :  0.01 %
# postdigital :  0.01 %
# professional :  0.01 %
# sign :  0.01 %
# far :  0.01 %
# spark :  0.01 %
# endless :  0.01 %
# aerospace :  0.01 %
# defense :  0.01 %
# concern :  0.01 %
# tip :  0.01 %
# emotional :  0.01 %
# auto :  0.01 %
# synthetic :  0.01 %
# single :  0.01 %
# from :  0.01 %
# abundance :  0.01 %
# hero :  0.01 %
# refinitiv :  0.01 %
# winner :  0.01 %
# education :  0.01 %
# insightful :  0.01 %
# overcome :  0.01 %
# speech :  0.01 %
# 70 :  0.01 %
# tailor :  0.01 %
# catapult :  0.01 %
# sure :  0.01 %
# light :  0.01 %
# deal :  0.01 %
# hard :  0.01 %
# trillion :  0.01 %
# price :  0.01 %
# cloudbase :  0.01 %
# major :  0.01 %
# electrification :  0.01 %
# consumption :  0.01 %
# patient :  0.01 %
# southern :  0.01 %
# cocacola :  0.01 %
# sponsor :  0.01 %
# atlanta :  0.01 %
# alongside :  0.01 %
# socialize :  0.01 %
# blur :  0.01 %
# roadmap :  0.01 %
# walk :  0.01 %
# multidimensional :  0.01 %
# thousand :  0.01 %
# saving :  0.01 %
# proactive :  0.01 %
# prevent :  0.01 %
# crucial :  0.01 %
# 13 :  0.01 %
# barrier :  0.01 %
# unwavering :  0.01 %
# algorithm :  0.01 %
# operating :  0.01 %
# restrict :  0.01 %
# visible :  0.01 %
# datadriven :  0.01 %
# multicultural :  0.01 %
# seramount :  0.01 %
# promote :  0.01 %
# perform :  0.01 %
# choice :  0.01 %
# cause :  0.01 %
# engineering :  0.01 %
# asia :  0.01 %
# firm :  0.01 %
# investor :  0.01 %
# chain :  0.01 %
# courage :  0.01 %
# record :  0.01 %
# recently :  0.01 %
# recycle :  0.01 %
# willing :  0.01 %
# metric :  0.01 %
# focused :  0.01 %
# openly :  0.01 %
# india :  0.01 %
# degree :  0.01 %
# acquire :  0.01 %
# breach :  0.01 %
# past :  0.01 %
# note :  0.01 %
# datacentric :  0.01 %
# achievement :  0.01 %
# standard :  0.01 %
# rest :  0.01 %
# challenging :  0.01 %
# academy :  0.01 %
# actively :  0.01 %
# warehouse :  0.01 %
# generation :  0.01 %
# disrupt :  0.01 %
# deploy :  0.01 %
# there :  0.01 %
# spectrum :  0.01 %
# poise :  0.01 %
# newfound :  0.01 %
# edgetake :  0.01 %
# integration :  0.01 %
# affect :  0.01 %
# still :  0.01 %
# data :  0.01 %
# racial :  0.01 %
# word :  0.01 %
# pilot :  0.01 %
# pack :  0.01 %
# policy :  0.01 %
# launch :  0.01 %
# drastically :  0.01 %
# consulting :  0.01 %
# exceptional :  0.01 %
# multipli :  0.01 %
# effect :  0.01 %
# 64 :  0.01 %
# tie :  0.01 %
# case :  0.01 %
# marketer :  0.01 %
# landit :  0.01 %
# wie :  0.01 %
# lean :  0.01 %
# optionborg :  0.01 %
# sell :  0.01 %
# revolutionizing :  0.01 %
# bloomberg :  0.01 %
# planscase :  0.01 %
# studiesstrategieslearn :  0.01 %
# bank :  0.01 %
# fast_company :  0.01 %
# close :  0.01 %
# discard :  0.01 %
# appointment :  0.01 %
# motivation :  0.01 %
# fitness :  0.01 %
# 15th :  0.01 %
# actual :  0.01 %
# away :  0.01 %
# cio :  0.01 %
# strengthen_sustainability :  0.01 %
# signal :  0.01 %
# burning :  0.01 %
# copy :  0.01 %
# acquisition :  0.01 %
# needs :  0.01 %
# rekha :  0.01 %
# joe :  0.01 %
# depa :  0.01 %
# loss :  0.01 %
# fulfil :  0.01 %
# struggle :  0.01 %
# current :  0.01 %
# tourism :  0.01 %
# collaborate :  0.01 %
# glasgow :  0.01 %
# vice :  0.01 %
# dubai :  0.01 %
# touchpoint :  0.01 %
# everywhere :  0.01 %
# techenabled :  0.01 %
# decisionmaking :  0.01 %
# position :  0.01 %
# or :  0.01 %
# opportunitysee :  0.01 %
# transparent :  0.01 %
# chairman :  0.01 %
# offering :  0.01 %
# radar :  0.01 %
# especially :  0.01 %
# strategically :  0.01 %
# predict :  0.01 %
# sap :  0.01 %
# fair :  0.01 %
# seismic :  0.01 %
# slow :  0.01 %
# highcaliber :  0.01 %
# customerobsesse :  0.01 %
# roi :  0.01 %
# form :  0.01 %
# uncertain :  0.01 %
# julie :  0.01 %
# ventilator :  0.01 %
# easton :  0.01 %
# bettingerbuckingham :  0.01 %
# donna :  0.01 %
# usual :  0.01 %
# state :  0.01 %
# hans :  0.01 %
# vestberg :  0.01 %
# profit :  0.01 %
# technological :  0.01 %
# fiction :  0.01 %
# blend :  0.01 %
# benchmark :  0.01 %
# nothing :  0.01 %
# image :  0.01 %
# tag :  0.01 %
# description :  0.01 %
# going :  0.01 %
# additional :  0.01 %
# final :  0.01 %
# determine :  0.01 %
# majekodunmi :  0.01 %
# she :  0.01 %
# ireland :  0.01 %
# regardless :  0.01 %
# wrap :  0.01 %
# andy :  0.01 %
# w :  0.01 %
# mathangi :  0.01 %
# making :  0.01 %
# what :  0.01 %
# greater :  0.01 %
# dimension :  0.01 %
# connectivitybase :  0.01 %
# mwc :  0.01 %
# participant :  0.01 %
# samta :  0.01 %
# kapoor :  0.01 %
# cluster :  0.01 %
# principle :  0.01 %
# broaden :  0.01 %
# nazi :  0.01 %
# persecution :  0.01 %
# preserve :  0.01 %
# forget :  0.01 %
# helped :  0.01 %
# sport :  0.01 %
# differentiation :  0.01 %
# influential :  0.01 %
# chros :  0.01 %
# kathleen :  0.01 %
# oreilly :  0.01 %
# jack :  0.01 %
# azagury :  0.01 %
# preview :  0.01 %
# village :  0.01 %
# agree :  0.01 %
# characteristic :  0.01 %
# geography :  0.01 %
# carefully :  0.01 %
# curate :  0.01 %
# wing :  0.01 %
# backstage :  0.01 %
# chart :  0.01 %
# overall :  0.01 %
# imagine :  0.01 %
# productive :  0.01 %
# box :  0.01 %
# flight :  0.01 %
# seat :  0.01 %
# fashion :  0.01 %
# fundamentally :  0.01 %
# awardwinning :  0.01 %
# okay :  0.01 %
# almost :  0.01 %
# often :  0.01 %
# actually :  0.01 %
# meta :  0.01 %
# kelly :  0.01 %
# monahan :  0.01 %
# 10yearold :  0.01 %
# computer :  0.01 %
# pga :  0.01 %
# summer :  0.01 %
# futureproof :  0.01 %
# getting :  0.01 %
# complexity :  0.01 %
# corner :  0.01 %
# edwin :  0.01 %
# web :  0.01 %
# philippine :  0.01 %
# airline :  0.01 %
# traveler :  0.01 %
# staff :  0.01 %
# fade :  0.01 %
# blind :  0.01 %
# teresa :  0.01 %
# impactful :  0.01 %
# annually :  0.01 %
# bailey :  0.01 %
# motivational :  0.01 %
# tedx :  0.01 %
# happiness :  0.01 %
# coach :  0.01 %
# club :  0.01 %
# avoid :  0.01 %
# 22 :  0.01 %
# mitigate :  0.01 %
# bt :  0.01 %
# cute :  0.01 %
# lose :  0.01 %
# antitransgender :  0.01 %
# violence :  0.01 %
# man :  0.01 %
# multitasker :  0.01 %
# expertly :  0.01 %
# forefront :  0.01 %
# participate :  0.01 %
# apart :  0.01 %
# obsolete :  0.01 %
# positioned :  0.01 %
# purchase :  0.01 %
# marketplace :  0.01 %
# bridge :  0.01 %
# room :  0.01 %
# apple :  0.01 %
# viewer :  0.01 %
# importantly :  0.01 %
# lay :  0.01 %
# machine :  0.01 %
# bingo :  0.01 %
# productcentric :  0.01 %
# enabler :  0.01 %
# ease :  0.01 %
# themselves :  0.01 %
# term :  0.01 %
# series :  0.01 %
# college :  0.01 %
# stigma :  0.01 %
# tamarah :  0.01 %
# dupervalbrownlee :  0.01 %
# mba :  0.01 %
# dheeraj :  0.01 %
# legacy :  0.01 %
# preference :  0.01 %
# martha :  0.01 %
# cotton :  0.01 %
# curtis :  0.01 %
# redesign :  0.01 %
# iconic :  0.01 %
# lseg :  0.01 %
# repetition :  0.01 %
# music :  0.01 %
# analyze :  0.01 %
# pattern :  0.01 %
# fun :  0.01 %
# whole :  0.01 %
# simplify :  0.01 %
# confident :  0.01 %
# carl :  0.01 %
# eliminate :  0.01 %
# eu :  0.01 %
# gas :  0.01 %
# estimate :  0.01 %
# secret :  0.01 %
# perfect :  0.01 %
# imagination :  0.01 %
# skille :  0.01 %
# 70000 :  0.01 %
# aim :  0.01 %
# buy :  0.01 %
# run :  0.01 %
# east :  0.01 %
# lake :  0.01 %
# historic :  0.01 %
# brandnew :  0.01 %
# simply :  0.01 %
# wallet :  0.01 %
# intensity :  0.01 %
# contact :  0.01 %
# shoot :  0.01 %
# ana :  0.01 %
# consequence :  0.01 %
# asset :  0.01 %
# differentiator :  0.01 %
# fuel :  0.01 %
# amid :  0.01 %
# competition :  0.01 %
# frontline :  0.01 %
# ciso :  0.01 %
# underrepresented :  0.01 %
# order :  0.01 %
# contribute :  0.01 %
# craft :  0.01 %
# encourage :  0.01 %
# delivery :  0.01 %
# eab :  0.01 %
# majority :  0.01 %
# apprenticeship :  0.01 %
# able :  0.01 %
# rah :  0.01 %
# thomas :  0.01 %
# strive :  0.01 %
# disabilityin :  0.01 %
# marine :  0.01 %
# inspirational :  0.01 %
# manager :  0.01 %
# highly :  0.01 %
# nonbinary :  0.01 %
# visibly :  0.01 %
# 120000 :  0.01 %
# national :  0.01 %
# glass :  0.01 %
# upskilling :  0.01 %
# vr :  0.01 %
# interview :  0.01 %
# tony :  0.01 %
# quest :  0.01 %
# retail :  0.01 %
# source :  0.01 %
# hint :  0.01 %
# internet :  0.01 %
# esg :  0.01 %
# cognitive :  0.01 %
# impairment :  0.01 %
# shortage :  0.01 %
# thrill :  0.01 %
# cheer :  0.01 %
# ranking :  0.01 %
# block :  0.01 %
# consideration :  0.01 %
# outside :  0.01 %
# profession :  0.01 %
# type :  0.01 %
# andrew :  0.01 %
# pioneer :  0.01 %
# 75 :  0.01 %
# audio :  0.01 %
# omniconnecte :  0.01 %
# cmos :  0.01 %
# treat :  0.01 %
# geopolitical :  0.01 %
# theme :  0.01 %
# stephanie :  0.01 %
# pleased :  0.01 %
# 9 :  0.01 %
# bar :  0.01 %
# turbulence :  0.01 %
# sector :  0.01 %
# nonprofit :  0.01 %
# entry :  0.01 %
# 3bl :  0.01 %
# authentic :  0.01 %
# self :  0.01 %
# fulfillment :  0.01 %
# protection :  0.01 %
# local :  0.01 %
# ad :  0.01 %
# fund :  0.01 %
# wherever :  0.01 %
# diversityinc :  0.01 %
# recommend :  0.01 %
# agile :  0.01 %
# coral :  0.01 %
# reef :  0.01 %
# harvard :  0.01 %
# review :  0.01 %
# edt :  0.01 %
# wellbeing :  0.01 %
# parent :  0.01 %
# air :  0.01 %
# continually :  0.01 %
# cultivate :  0.01 %
# sustainably :  0.01 %
# endtoendless :  0.01 %
# privilege :  0.01 %
# mining :  0.01 %
# metal :  0.01 %
# helps :  0.01 %
# transgender :  0.01 %
# 63 :  0.01 %
# elimination :  0.01 %
# track :  0.01 %
# thread :  0.01 %
# weave :  0.01 %
# yesterday :  0.01 %
# jefferson :  0.01 %
# wang :  0.01 %
# recap :  0.01 %
# simplicity :  0.01 %
# lifestyle :  0.01 %
# multiply :  0.01 %
# lever :  0.01 %
# clinical :  0.01 %
# trial :  0.01 %
# official :  0.01 %
# accelerator :  0.01 %
# woman_list :  0.01 %
# accentures :  0.01 %
# angel :  0.01 %
# optimism :  0.01 %
# wish :  0.01 %
# supplier :  0.01 %
# complete :  0.01 %
# tangible :  0.01 %
# stakeholdercentricity :  0.01 %
# fire :  0.01 %
# burnedout :  0.01 %
# clutter :  0.01 %
# showcase :  0.01 %
# produce :  0.01 %
# lower :  0.01 %
# norway :  0.01 %
# plastic :  0.01 %
# enzyme :  0.01 %
# sort :  0.01 %
# paper :  0.01 %
# sensor :  0.01 %
# receive :  0.01 %
# place_work :  0.01 %
# lgbtq :  0.01 %
# accountable :  0.01 %
# 674000 :  0.01 %
# dataled :  0.01 %
# translate :  0.01 %
# 600000 :  0.01 %
# brilliant :  0.01 %
# roof :  0.01 %
# capitalism :  0.01 %
# channel :  0.01 %
# south :  0.01 %
# america :  0.01 %
# tail :  0.01 %
# tactic :  0.01 %
# diminish :  0.01 %
# recent :  0.01 %
# director :  0.01 %
# sacrifice :  0.01 %
# reliability :  0.01 %
# gamification :  0.01 %
# reduction :  0.01 %
# 5300000 :  0.01 %
# 2part :  0.01 %
# odd :  0.01 %
# timely :  0.01 %
# as :  0.01 %
# unequivocally :  0.01 %
# nationally :  0.01 %
# determined :  0.01 %
# ndcs :  0.01 %
# augment :  0.01 %
# promotion :  0.01 %
# information :  0.01 %
# anticipate :  0.01 %
# procurement :  0.01 %
# un :  0.01 %
# crossindustry :  0.01 %
# connectivity :  0.01 %
# conference :  0.01 %
# remarkable :  0.01 %
# pivotal :  0.01 %
# option :  0.01 %
# accurate :  0.01 %
# peter :  0.01 %
# lacy :  0.01 %
# strengthen_dna :  0.01 %
# peoplework :  0.01 %
# build_sustainable :  0.01 %
# compressed :  0.01 %
# for :  0.01 %
# reframe :  0.01 %
# message :  0.01 %
# 4_key :  0.01 %
# tenet_continuum :  0.01 %
# competitor_share :  0.01 %
# unleash_competitiveness :  0.01 %
# expo :  0.01 %
# congratulate :  0.01 %
# york :  0.01 %
# studio :  0.01 %
# september :  0.01 %
# stage :  0.01 %
# ourselves :  0.01 %
# scientific :  0.01 %
# keeping :  0.01 %
# decentralizing :  0.01 %
# globally :  0.01 %
# locally :  0.01 %
# brian :  0.01 %
# whipple :  0.01 %
# significance :  0.01 %
# try :  0.01 %
# sneak :  0.01 %
# arjun :  0.01 %
# bedi :  0.01 %
# concept :  0.01 %
# remain :  0.01 %
# debt :  0.01 %
# inclusivity :  0.01 %
# news :  0.01 %
# 80 :  0.01 %
# prescription :  0.01 %
# hope :  0.01 %
# downturn :  0.01 %
# house :  0.01 %
# homeownership :  0.01 %
# scoop :  0.01 %
# wakeup :  0.01 %
# nick :  0.01 %
# select :  0.01 %
# 700 :  0.01 %
# nonpartisan :  0.01 %
# defend :  0.01 %
# vote :  0.01 %
# oppose :  0.01 %
# discriminatory :  0.01 %
# legislation :  0.01 %
# eligible :  0.01 %
# voter :  0.01 %
# cast :  0.01 %
# ballot :  0.01 %
# bigotry :  0.01 %
# respect :  0.01 %
# tolerance :  0.01 %
# openness :  0.01 %
# deeply :  0.01 %
# asian :  0.01 %
# survival :  0.01 %
# stall :  0.01 %
# steady :  0.01 %
# hyperscaler :  0.01 %
# wonder :  0.01 %
# exposure :  0.01 %
# retention :  0.01 %
# credibility :  0.01 %
# press :  0.01 %
# amongst :  0.01 %
# 500k :  0.01 %
# shaper :  0.01 %
# recover :  0.01 %
# covid19 :  0.01 %
# migrate :  0.01 %
# along :  0.01 %
# roundtable :  0.01 %
# integrity :  0.01 %
# inflection :  0.01 %
# trailblaze :  0.01 %
# cxos :  0.01 %
# visionary :  0.01 %
# businessperson :  0.01 %
# assessment :  0.01 %
# reset :  0.01 %
# girl :  0.01 %
# code :  0.01 %
# nhs :  0.01 %
# 3x :  0.01 %
# scaler :  0.01 %
# alibaba :  0.01 %
# 35 :  0.01 %
# inequality :  0.01 %
# send :  0.01 %
# representation :  0.01 %
# african :  0.01 %
# black :  0.01 %
# bright :  0.01 %
# sheet :  0.01 %
# servicenow :  0.01 %
# lincoln :  0.01 %
# tick :  0.01 %
# fill :  0.01 %
# depend :  0.01 %
# urgent :  0.01 %
# prediction :  0.01 %
# sync :  0.01 %
# belief :  0.01 %
# nellie :  0.01 %
# borrero :  0.01 %
# resourcing :  0.01 %
# fluctuating :  0.01 %
# productivity :  0.01 %
# phase :  0.01 %
# skilled :  0.01 %
# companytocompany :  0.01 %
# deputy :  0.01 %
# pm :  0.01 %
# friday :  0.01 %
# page :  0.01 %
# dramatically :  0.01 %
# techclash :  0.01 %
# ctio :  0.01 %
# webcast :  0.01 %
# feb :  0.01 %
# switch :  0.01 %
# why :  0.01 %
# trending :  0.01 %
# thompson :  0.01 %
# clearly :  0.01 %
# flexible :  0.01 %
# multidisciplinary :  0.01 %
# fjord :  0.01 %
# comes :  0.01 %
# maximum :  0.01 %
# off :  0.01 %
# lot :  0.01 %
# g :  0.01 %
# usually :  0.01 %
# candid :  0.01 %
# gamechange :  0.01 %
# experiment :  0.01 %
# cmco :  0.01 %
# amy :  0.01 %
# low :  0.01 %
# 10000 :  0.01 %
# sander :  0.01 %
# van :  0.01 %
# noordende :  0.01 %
# computational :  0.01 %
# enter :  0.0 %
# bond :  0.0 %
# advancement :  0.0 %
# disruptionproof :  0.0 %
# workflow :  0.0 %
# merge :  0.0 %
# onetime :  0.0 %
# execution :  0.0 %
# anymore :  0.0 %
# seek :  0.0 %
# boldly :  0.0 %
# animation :  0.0 %
# vibe :  0.0 %
# frame :  0.0 %
# guideline :  0.0 %
# sheherhers :  0.0 %
# disengage :  0.0 %
# notion :  0.0 %
# officelearn :  0.0 %
# absolutely :  0.0 %
# pass :  0.0 %
# halfway :  0.0 %
# plus :  0.0 %
# dogswatch :  0.0 %
# buzz :  0.0 %
# while :  0.0 %
# countdown :  0.0 %
# telecommunication :  0.0 %
# hour :  0.0 %
# workday :  0.0 %
# establish :  0.0 %
# straight :  0.0 %
# 5th :  0.0 %
# 360º :  0.0 %
# borderstech :  0.0 %
# qualcomm :  0.0 %
# avenue :  0.0 %
# beautiful :  0.0 %
# trophy :  0.0 %
# v360 :  0.0 %
# thinkread :  0.0 %
# remembrance :  0.0 %
# pause :  0.0 %
# antisemitism :  0.0 %
# racismaccenture :  0.0 %
# memorial :  0.0 %
# history :  0.0 %
# nazism :  0.0 %
# pathways :  0.0 %
# csp :  0.0 %
# lowcarbon :  0.0 %
# attend :  0.0 %
# athletic :  0.0 %
# untold :  0.0 %
# side :  0.0 %
# heroeslearn :  0.0 %
# intimately :  0.0 %
# ft :  0.0 %
# hugh :  0.0 %
# evans :  0.0 %
# adanna :  0.0 %
# steinacker :  0.0 %
# pgle :  0.0 %
# equip :  0.0 %
# innovationour :  0.0 %
# csuite :  0.0 %
# highre :  0.0 %
# reinventionsee :  0.0 %
# wef23 :  0.0 %
# davo :  0.0 %
# reinventor :  0.0 %
# organizationdownload :  0.0 %
# 8 :  0.0 %
# moving :  0.0 %
# mainstream :  0.0 %
# transcend :  0.0 %
# status :  0.0 %
# twoway :  0.0 %
# fandriven :  0.0 %
# pricing :  0.0 %
# custom :  0.0 %
# nft :  0.0 %
# ticket :  0.0 %
# restore :  0.0 %
# player :  0.0 %
# moderate :  0.0 %
# choose :  0.0 %
# stadium :  0.0 %
# bucket :  0.0 %
# outer :  0.0 %
# disneys :  0.0 %
# studiolab :  0.0 %
# storytelle :  0.0 %
# ideal :  0.0 %
# alternative :  0.0 %
# haul :  0.0 %
# airplane :  0.0 %
# comfortable :  0.0 %
# imagining :  0.0 %
# 2028 :  0.0 %
# hardt :  0.0 %
# cabin1 :  0.0 %
# terrain :  0.0 %
# crm :  0.0 %
# volumetric :  0.0 %
# onto :  0.0 %
# floor :  0.0 %
# snow :  0.0 %
# boot :  0.0 %
# january :  0.0 %
# phd :  0.0 %
# fluency :  0.0 %
# healthy :  0.0 %
# escalate :  0.0 %
# either :  0.0 %
# rein :  0.0 %
# desire :  0.0 %
# 600k :  0.0 %
# homeless :  0.0 %
# out :  0.0 %
# intern :  0.0 %
# nyc :  0.0 %
# chicago :  0.0 %
# toronto :  0.0 %
# relevancy :  0.0 %
# researchbacked :  0.0 %
# earn :  0.0 %
# ignore :  0.0 %
# opportunity_add :  0.0 %
# prioritize :  0.0 %
# retentionfrom :  0.0 %
# little :  0.0 %
# delighted :  0.0 %
# bestmanaged :  0.0 %
# accord :  0.0 %
# street :  0.0 %
# journal :  0.0 %
# drucker :  0.0 %
# musthave :  0.0 %
# vacation :  0.0 %
# wifi :  0.0 %
# firstclass :  0.0 %
# experiencethere :  0.0 %
# costeffective :  0.0 %
# avanade :  0.0 %
# techbased :  0.0 %
# breakneck :  0.0 %
# worlds :  0.0 %
# interbrand :  0.0 %
# youtube :  0.0 %
# baileys :  0.0 %
# alt :  0.0 %
# textpurple :  0.0 %
# background :  0.0 %
# spotlight :  0.0 %
# water :  0.0 %
# ethiopa :  0.0 %
# technologist :  0.0 %
# outpace :  0.0 %
# rate :  0.0 %
# nine :  0.0 %
# percentage :  0.0 %
# advocate :  0.0 %
# size :  0.0 %
# aisports :  0.0 %
# cohesion :  0.0 %
# largescale :  0.0 %
# simulation :  0.0 %
# catharina :  0.0 %
# baileysave :  0.0 %
# further :  0.0 %
# chase :  0.0 %
# refocus :  0.0 %
# contradiction :  0.0 %
# rather :  0.0 %
# 21 :  0.0 %
# aunt :  0.0 %
# raquel :  0.0 %
# wanted :  0.0 %
# land :  0.0 %
# needsthe :  0.0 %
# shine :  0.0 %
# 93 :  0.0 %
# vow :  0.0 %
# combat :  0.0 %
# serendipitous :  0.0 %
# widen :  0.0 %
# pool :  0.0 %
# being :  0.0 %
# peaceful :  0.0 %
# reemphasize :  0.0 %
# correctly :  0.0 %
# securely :  0.0 %
# assess :  0.0 %
# pocket :  0.0 %
# actionable :  0.0 %
# modernization :  0.0 %
# resolve :  0.0 %
# disconnect :  0.0 %
# teammate :  0.0 %
# assistive :  0.0 %
# 605 :  0.0 %
# tremendous :  0.0 %
# genuine :  0.0 %
# forrester :  0.0 %
# 16000 :  0.0 %
# icon :  0.0 %
# politic :  0.0 %
# nytime :  0.0 %
# summit :  0.0 %
# 1718 :  0.0 %
# unpatched :  0.0 %
# untested :  0.0 %
# expose :  0.0 %
# attacker :  0.0 %
# exploit :  0.0 %
# professionalization :  0.0 %
# prepared :  0.0 %
# crises :  0.0 %
# 16x :  0.0 %
# dividend :  0.0 %
# inaugural :  0.0 %
# glassdoor :  0.0 %
# mit :  0.0 %
# sloan :  0.0 %
# pressure :  0.0 %
# oversight :  0.0 %
# cover :  0.0 %
# hail :  0.0 %
# congrats :  0.0 %
# owner :  0.0 %
# advisor :  0.0 %
# detroit :  0.0 %
# exchange :  0.0 %
# chinabased :  0.0 %
# industryleade :  0.0 %
# newly :  0.0 %
# appoint :  0.0 %
# december :  0.0 %
# hell :  0.0 %
# oversee :  0.0 %
# acceleration :  0.0 %
# scaling :  0.0 %
# 360degree :  0.0 %
# jump :  0.0 %
# fundaula :  0.0 %
# elearne :  0.0 %
# myrtle :  0.0 %
# probably :  0.0 %
# na :  0.0 %
# professionally :  0.0 %
# personally :  0.0 %
# brac :  0.0 %
# planning :  0.0 %
# coloured :  0.0 %
# africa :  0.0 %
# representative :  0.0 %
# premier :  0.0 %
# buckingham :  0.0 %
# techdriven :  0.0 %
# q4 :  0.0 %
# fy20 :  0.0 %
# 100000 :  0.0 %
# 3b :  0.0 %
# timeline :  0.0 %
# hence :  0.0 %
# several :  0.0 %
# yearscongrat :  0.0 %
# karthik :  0.0 %
# narain :  0.0 %
# aidriven :  0.0 %
# governmentcitizen :  0.0 %
# 30000 :  0.0 %
# testament :  0.0 %
# reaffirm :  0.0 %
# justice :  0.0 %
# june :  0.0 %
# jeanmarc :  0.0 %
# consistently :  0.0 %
# counter :  0.0 %
# twothird :  0.0 %
# 9th :  0.0 %
# 500000 :  0.0 %
# ambassador :  0.0 %
# hybrid :  0.0 %
# deployment :  0.0 %
# private :  0.0 %
# 71 :  0.0 %
# siloed :  0.0 %
# synche :  0.0 %
# robotic :  0.0 %
# mynav :  0.0 %
# guesswork :  0.0 %
# solutioning :  0.0 %
# objective :  0.0 %
# spread :  0.0 %
# rollsroyce :  0.0 %
# production :  0.0 %
# 13k :  0.0 %
# consortium :  0.0 %
# have :  0.0 %
# arrival :  0.0 %
# spain :  0.0 %
# singapore :  0.0 %
# mercedesbenz :  0.0 %
# consistent :  0.0 %
# relevant :  0.0 %
# uplift :  0.0 %
# recommendation :  0.0 %
# scalable :  0.0 %
# moneta :  0.0 %
# ramp :  0.0 %
# experimentation :  0.0 %
# q3 :  0.0 %
# 77 :  0.0 %
# 195 :  0.0 %
