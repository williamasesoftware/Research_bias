# %%
import pandas as pd
df = pd.read_csv("articles_paragraphs.csv")

# %%
df_eng = df[df['language_code'] =='en'].reset_index()

# %%
df_eng
# Out:
#      index  Unnamed: 0               article_name  \
# 0        0           0  Enhance medicine using AI
# 1        1           1  Enhance medicine using AI
# 2        2           2  Enhance medicine using AI
# 3        3           3  Enhance medicine using AI
# 4        4           4  Enhance medicine using AI
# ..     ...         ...                        ...
# 383    537         537    BI for making decisions
# 384    538         538    BI for making decisions
# 385    539         539    BI for making decisions
# 386    540         540    BI for making decisions
# 387    541         541    BI for making decisions
#
#                                                content  \
# 0    During the last decades, AI transformed multip...
# 1    The first time AI helped humans research was i...
# 2    AI is turning the drug-discovery paradigm upsi...
# 3    Another contribution of AI to this field was m...
# 4    Then this information is used to create a repr...
# ...
